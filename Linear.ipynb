# %% [markdown]
# ## Exploratory Analisys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import io

# %%
data = pd.read_csv('sensors.csv', sep = ',')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6928 entries, 0 to 6927
# Data columns (total 95 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 6927 non-null   object
#  1   Total Voltage (V)    6927 non-null   object
#  2   Average Voltage (V)  6927 non-null   float64
#  3   sensor 1             6927 non-null   float64
#  4   sensor 2             6927 non-null   float64
#  5   sensor 3             6927 non-null   float64
#  6   sensor 4             6927 non-null   float64
#  7   sensor 5             6927 non-null   float64
#  8   sensor 6             6927 non-null   float64
#  9   sensor 7             6927 non-null   float64
#  10  sensor 8             6927 non-null   float64
#  11  sensor 9             6927 non-null   float64
#  12  sensor 10            6927 non-null   float64
#  13  sensor 11            6927 non-null   float64
#  14  sensor 12            6927 non-null   float64
#  15  sensor 13            6927 non-null   float64
#  16  sensor 14            6927 non-null   float64
#  17  sensor 15            6927 non-null   float64
#  18  sensor 16            6927 non-null   float64
#  19  sensor 17            6927 non-null   float64
#  20  sensor 18            6927 non-null   float64
#  21  sensor 19            6927 non-null   float64
#  22  sensor 20            6927 non-null   float64
#  23  sensor 21            6927 non-null   float64
#  24  sensor 22            6927 non-null   float64
#  25  sensor 23            6927 non-null   float64
#  26  sensor 24            6927 non-null   float64
#  27  sensor 25            6927 non-null   float64
#  28  sensor 26            6927 non-null   float64
#  29  sensor 27            6927 non-null   float64
#  30  sensor 28            6927 non-null   float64
#  31  sensor 29            6927 non-null   float64
#  32  sensor 30            6927 non-null   float64
#  33  sensor 31            6927 non-null   float64
#  34  sensor 32            6927 non-null   float64
#  35  sensor 33            6927 non-null   float64
#  36  sensor 34            6927 non-null   float64
#  37  sensor 35            6927 non-null   float64
#  38  sensor 36            6927 non-null   float64
#  39  sensor 37            6927 non-null   float64
#  40  sensor 38            6927 non-null   float64
#  41  sensor 39            6927 non-null   float64
#  42  sensor 40            6927 non-null   float64
#  43  sensor 41            6927 non-null   float64
#  44  sensor 42            6927 non-null   float64
#  45  sensor 43            6927 non-null   float64
#  46  sensor 44            6927 non-null   float64
#  47  sensor 45            6927 non-null   float64
#  48  sensor 46            6927 non-null   float64
#  49  sensor 47            6927 non-null   float64
#  50  sensor 48            6927 non-null   float64
#  51  sensor 49            6927 non-null   float64
#  52  sensor 50            6927 non-null   float64
#  53  sensor 51            6927 non-null   float64
#  54  sensor 52            6927 non-null   float64
#  55  sensor 53            6927 non-null   float64
#  56  sensor 54            6927 non-null   float64
#  57  sensor 55            6927 non-null   float64
#  58  sensor 56            6927 non-null   float64
#  59  sensor 57            6927 non-null   float64
#  60  sensor 58            6927 non-null   float64
#  61  sensor 59            6927 non-null   float64
#  62  sensor 60            6927 non-null   float64
#  63  sensor 61            6927 non-null   float64
#  64  sensor 62            6927 non-null   float64
#  65  sensor 63            6927 non-null   float64
#  66  sensor 64            6927 non-null   float64
#  67  sensor 65            6927 non-null   float64
#  68  sensor 66            6927 non-null   float64
#  69  sensor 67            6927 non-null   float64
#  70  sensor 68            6927 non-null   float64
#  71  sensor 69            6927 non-null   float64
#  72  sensor 70            6927 non-null   float64
#  73  sensor 71            6927 non-null   float64
#  74  sensor 72            6927 non-null   float64
#  75  sensor 73            6927 non-null   float64
#  76  sensor 74            6927 non-null   float64
#  77  sensor 75            6927 non-null   float64
#  78  sensor 76            6927 non-null   float64
#  79  sensor 77            6927 non-null   float64
#  80  sensor 78            6927 non-null   float64
#  81  sensor 79            6927 non-null   float64
#  82  sensor 80            6927 non-null   float64
#  83  sensor 81            6927 non-null   float64
#  84  sensor 82            6927 non-null   float64
#  85  sensor 83            6927 non-null   float64
#  86  sensor 84            6927 non-null   float64
#  87  sensor 85            6927 non-null   float64
#  88  sensor 86            6927 non-null   float64
#  89  sensor 87            6927 non-null   float64
#  90  sensor 88            6927 non-null   float64
#  91  sensor 89            6927 non-null   float64
#  92  sensor 90            6927 non-null   float64
#  93  sensor 91            6927 non-null   float64
#  94  sensor 92            6927 non-null   float64
# dtypes: float64(93), object(2)
# memory usage: 5.0+ MB

# %%
#Dropping columns that are not relevant for the model  
data = data.drop(columns = ['Total Voltage (V)', 'Average Voltage (V)'])

#Converting the 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)


#Checking the first few rows of the updated dataset
data.head(3)
# Out:
#                  Date    sensor 1    sensor 2    sensor 3    sensor 4  \
# 0 2023-04-03 03:00:01  119.121812  115.827723  116.327884  117.658852
# 1 2023-04-03 04:00:01  121.092423  117.628034  118.118468  119.575351
# 2 2023-04-03 05:00:01  121.893561  118.410648  118.866724  120.405980
#
#      sensor 5    sensor 6    sensor 7    sensor 8    sensor 9  ...  \
# 0  117.589612  117.496657  115.859532  114.603809  118.058141  ...
# 1  119.504139  119.387818  117.598619  116.261870  119.998991  ...
# 2  120.332878  120.213393  118.315624  116.951690  120.807357  ...
#
#     sensor 83   sensor 84   sensor 85   sensor 86   sensor 87   sensor 88  \
# 0  115.647812  114.299245  116.471634  115.380364  115.110607  115.910664
# 1  117.329442  115.892439  118.243012  117.071528  116.750911  117.634598
# 2  118.087727  116.615680  119.053043  117.826122  117.492186  118.392878
#
#     sensor 89   sensor 90   sensor 91   sensor 92
# 0  117.049984  114.031306  113.770388  115.565692
# 1  118.956594  115.616289  115.338720  117.255179
# 2  119.695606  116.356843  116.066697  118.036934
#
# [3 rows x 93 columns]

# %% [markdown]
# The fig above show when the site shutdown, and thats it's not a good messure to bring to the model

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data = data, y='sensor 34', x='Date')
plt.title('Voltage Registred by Sensor 34')
plt.ylim(121.5, 130)
plt.xlabel('Date')
plt.ylabel('Voltage')
plt.show()

# %%
data = data[data['sensor 34'] > 121.5 ]
data['sensor 34'].describe()
# Out:
# count    6658.000000
# mean      123.555389
# std         0.805674
# min       121.585035
# 25%       122.852568
# 50%       123.424118
# 75%       124.263571
# max       125.811034
# Name: sensor 34, dtype: float64

# %%
average_s34 = data.groupby(data['Date'].dt.date)['sensor 34'].mean()
average_s34 = average_s34.reset_index()
average_s34.rename(columns={'Date': 'average_daily'}, inplace=True)
average_s34
# Out:
#     average_daily   sensor 34
# 0      2023-04-04  122.444449
# 1      2023-04-05  122.511457
# 2      2023-04-06  122.462247
# 3      2023-04-07  122.558795
# 4      2023-04-08  122.635337
# ..            ...         ...
# 301    2024-04-07  124.854037
# 302    2024-04-08  125.114604
# 303    2024-04-09  124.935289
# 304    2024-04-10  124.929781
# 305    2024-04-11  124.920366
#
# [306 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data = average_s34, x='average_daily', y='sensor 34')
plt.title('Voltage Registred by Sensor 34')
plt.ylim(121.5, 130)
plt.xlabel('Date')
plt.ylabel('Voltage')
plt.show()

# %%
average_s34['diff'] = average_s34['sensor 34'].diff()
average_s34.dropna(inplace=True)
average_s34.head(3)
# Out:
#   average_daily   sensor 34      diff
# 1    2023-04-05  122.511457  0.067008
# 2    2023-04-06  122.462247 -0.049210
# 3    2023-04-07  122.558795  0.096548

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
plot_acf(average_s34['sensor 34'], lags=30, ax=axes[0], alpha=0.05)
axes[0].set_title('Autocorrelação (ACF) - Sensor 34', fontsize=13)
axes[0].set_xlabel('Lags')
axes[0].set_ylabel('Correlação')
axes[0].grid(True, alpha=0.3)

plot_pacf(average_s34['sensor 34'], lags=30, method='yw', ax=axes[1], alpha=0.05)
axes[1].set_title('Autocorrelação Parcial (PACF) - Sensor 34', fontsize=13)
axes[1].set_xlabel('Lags')
axes[1].set_ylabel('Correlação Parcial')
axes[1].grid(True, alpha=0.3)

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
plot_acf(average_s34['diff'], lags=30, ax=axes[0], alpha=0.05)
axes[0].set_title('Autocorrelação (ACF) - Diff Sensor 34', fontsize=13)
axes[0].set_xlabel('Lags')
axes[0].set_ylabel('Correlação')
axes[0].grid(True, alpha=0.3)

plot_pacf(average_s34['diff'], lags=30, method='yw', ax=axes[1], alpha=0.05)
axes[1].set_title('Autocorrelação Parcial (PACF) - Diff Sensor 34', fontsize=13)
axes[1].set_xlabel('Lags')
axes[1].set_ylabel('Correlação Parcial')
axes[1].grid(True, alpha=0.3)

# %% [markdown]
# ## Features

# %% [markdown]
# Separating into test and training sets

# %%
for i in range(1, 3, 1):
        average_s34[f'shift_{i}'] = average_s34['sensor 34'].shift(i)
average_s34.dropna(inplace=True)

y = average_s34['sensor 34'].values.reshape(-1, 1).astype('float32')
X = average_s34[[f'shift_{i}' for i in range(1, 3)]].values.astype('float32')  # Usando os valores dos 8 dias anteriores como recursos


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False) #shuffle=False to maintain the time series order

# %%
preview = pd.DataFrame(X_train, columns=[f'shift_{i}' for i in range(1, 3)])
preview.head(3)
# Out:
#       shift_1     shift_2
# 0  122.462250  122.511459
# 1  122.558792  122.462250
# 2  122.635338  122.558792

# %%
X.shape, y.shape
# Out:
# ((303, 2), (303, 1))

# %% [markdown]
# Normalizando dados

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test) #Evitar datalake

# %% [markdown]
# Hiperparâmetros

# %%
TAXA_APRENDIZADO = 0.001  # Tamanho do "passo" na otimização (ex: 0.1, 0.01, 0.001)
EPOCAS = 200             # Quantas vezes a rede verá todo o dataset
TAMANHO_LOTE = 10     # Batch size

# %% [markdown]
# Aplicando o treinamento

# %%
#Construção da arquitetura

#Camada de Entrada
model_mlp = Sequential([Dense(32, # 64 Neurônio nesta camada (Z = W*X + b)
                                  input_shape=(2,), # Quantidade de variáveis que vão entrar ( Z = w1*x1 + w2*x2 + b)
                                  activation='linear') ]) # Especificando qual vai ser o tipo de ativação. Ex: reLu, linear, tanh, sigmoid...


#Camada Oculta 1
model_mlp.add(Dense(16, activation='linear'))

#Camada de Saída
model_mlp.add(Dense(1, activation='linear')) # 1 Neurônio nesta camada (Z = W*X + b) --- IGNORE ---, ativação linear para regressão


#Configuração
model_mlp.compile(
    optimizer=Adam(learning_rate=TAXA_APRENDIZADO), #Aplicação do modelo de Gradiente descendente, usando o leanning rate proposto
    loss='mse', # Qual a função da loss. Nesse caso o mse é (Z - F(x1,x2))²
    metrics=['mae'] # Erro Médio Absoluto para termos uma métrica mais legível
)

#Treinamento
historico = model_mlp.fit(
    X_train_scaled, y_train, #Indica quais são as bases
    epochs=EPOCAS, batch_size=TAMANHO_LOTE, #O batch_size é a batelada de cada iteração (epoch) que será calculada
    verbose=1 # Mude para 1 se quiser ver o log de cada época
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/200
# c:\Projeto de Manutenção\Maintenance-prediction\.venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15078.1641 - mae: 122.7920
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14801.9023 - mae: 121.6623
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14375.5537 - mae: 119.8954
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13649.5527 - mae: 116.8188
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12497.8389 - mae: 111.7495
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10824.6582 - mae: 103.9056
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8681.1729 - mae: 92.8057
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6294.3018 - mae: 78.4919
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4043.3567 - mae: 61.5223
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2323.0098 - mae: 43.9360
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1310.8906 - mae: 31.0814
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 903.8601 - mae: 26.2209
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 782.2659 - mae: 24.6122
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 748.9722 - mae: 24.0121
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 726.0927 - mae: 23.6445
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 704.0564 - mae: 23.2562
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 680.5621 - mae: 22.8666
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 657.2681 - mae: 22.4780
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 634.1422 - mae: 22.0815
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 610.8497 - mae: 21.6777
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 587.1245 - mae: 21.2600
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 565.0099 - mae: 20.8594
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 542.8712 - mae: 20.4476
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 522.3824 - mae: 20.0159
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 498.2048 - mae: 19.5659
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 475.6990 - mae: 19.1168
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 454.9555 - mae: 18.7015
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 434.7737 - mae: 18.2374
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 412.1740 - mae: 17.8010
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 390.2405 - mae: 17.3214
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 371.4964 - mae: 16.8738
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 350.8940 - mae: 16.4166
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 331.7025 - mae: 15.9441
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 312.8317 - mae: 15.5021
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 293.6273 - mae: 15.0271
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 277.3115 - mae: 14.5927
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 259.6067 - mae: 14.1020
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 242.1220 - mae: 13.6343
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 225.3334 - mae: 13.1317
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 209.9174 - mae: 12.6948
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 195.0243 - mae: 12.2226
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 179.1850 - mae: 11.6846
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 164.8453 - mae: 11.2437
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 150.8893 - mae: 10.7438
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 138.2348 - mae: 10.2743
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 126.5728 - mae: 9.8576
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 114.3935 - mae: 9.3380
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 103.8876 - mae: 8.9250
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 93.6976 - mae: 8.4462
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 83.9904 - mae: 7.9934
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 75.0235 - mae: 7.5589
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 67.0114 - mae: 7.1565
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 59.5027 - mae: 6.7487
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 52.6395 - mae: 6.3280
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.3960 - mae: 5.9474
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.6368 - mae: 5.5365
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.2788 - mae: 5.1879
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30.5998 - mae: 4.8288
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26.4258 - mae: 4.4684
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.6163 - mae: 4.1443
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.2380 - mae: 3.8353
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 16.0666 - mae: 3.4994
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.5619 - mae: 3.2074
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.3954 - mae: 2.9410
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.5098 - mae: 2.6784
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9037 - mae: 2.4530
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4831 - mae: 2.2141
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3250 - mae: 2.0111
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4072 - mae: 1.8171
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5690 - mae: 1.6361
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8654 - mae: 1.4589
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3298 - mae: 1.3059
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8736 - mae: 1.1890
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4718 - mae: 1.0365
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1780 - mae: 0.9253
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9568 - mae: 0.8412
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7634 - mae: 0.7340
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6009 - mae: 0.6602
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4828 - mae: 0.5890
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3878 - mae: 0.5136
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3040 - mae: 0.4626
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2401 - mae: 0.4026
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1970 - mae: 0.3552
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1610 - mae: 0.3230
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1319 - mae: 0.2866
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1112 - mae: 0.2574
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0946 - mae: 0.2314
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0823 - mae: 0.2097
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0730 - mae: 0.1919
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0659 - mae: 0.1792
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0612 - mae: 0.1670
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0569 - mae: 0.1579
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0545 - mae: 0.1521
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0536 - mae: 0.1506
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0510 - mae: 0.1441
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0493 - mae: 0.1408
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0487 - mae: 0.1405
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0486 - mae: 0.1395
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0477 - mae: 0.1401
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0474 - mae: 0.1375
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0473 - mae: 0.1402
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0468 - mae: 0.1374
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0462 - mae: 0.1378
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0465 - mae: 0.1398
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0460 - mae: 0.1377
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0463 - mae: 0.1390
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0468 - mae: 0.1402
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0459 - mae: 0.1399
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0458 - mae: 0.1391
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0461 - mae: 0.1389
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0463 - mae: 0.1415
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0459 - mae: 0.1394
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0457 - mae: 0.1408
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0462 - mae: 0.1426
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0456 - mae: 0.1393
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0453 - mae: 0.1383
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0454 - mae: 0.1385
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0465 - mae: 0.1410
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0463 - mae: 0.1418
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0474 - mae: 0.1418
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0454 - mae: 0.1383
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0451 - mae: 0.1386
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0450 - mae: 0.1393
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0457 - mae: 0.1385
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0454 - mae: 0.1396
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0457 - mae: 0.1414
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0449 - mae: 0.1372
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0447 - mae: 0.1383
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0447 - mae: 0.1377
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0450 - mae: 0.1391
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0444 - mae: 0.1395
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0447 - mae: 0.1373
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0455 - mae: 0.1389
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0445 - mae: 0.1397
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0455 - mae: 0.1393
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0452 - mae: 0.1446
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0454 - mae: 0.1393
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0463 - mae: 0.1449
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0445 - mae: 0.1371
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0451 - mae: 0.1420
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0444 - mae: 0.1385
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0444 - mae: 0.1369
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0442 - mae: 0.1377
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0440 - mae: 0.1372
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0447 - mae: 0.1386
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0435 - mae: 0.1359
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0442 - mae: 0.1374
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0444 - mae: 0.1377
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0438 - mae: 0.1361
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0442 - mae: 0.1362
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0440 - mae: 0.1366
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0438 - mae: 0.1378
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0436 - mae: 0.1348
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0437 - mae: 0.1362
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0436 - mae: 0.1376
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0443 - mae: 0.1364
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0437 - mae: 0.1359
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0433 - mae: 0.1361
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0437 - mae: 0.1359
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0437 - mae: 0.1367
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0439 - mae: 0.1371
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0443 - mae: 0.1397
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0436 - mae: 0.1360
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0436 - mae: 0.1375
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0433 - mae: 0.1369
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0433 - mae: 0.1374
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0430 - mae: 0.1359
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0438 - mae: 0.1358
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0433 - mae: 0.1377
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0429 - mae: 0.1387
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0453 - mae: 0.1442
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0434 - mae: 0.1402
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0446 - mae: 0.1395
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0435 - mae: 0.1380
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0450 - mae: 0.1418
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0451 - mae: 0.1381
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0450 - mae: 0.1432
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0452 - mae: 0.1412
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0439 - mae: 0.1388
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0438 - mae: 0.1372
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0434 - mae: 0.1368
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0429 - mae: 0.1349
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0430 - mae: 0.1366
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0434 - mae: 0.1352
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0453 - mae: 0.1431
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0436 - mae: 0.1413
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0436 - mae: 0.1375
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0435 - mae: 0.1369
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0435 - mae: 0.1347
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0436 - mae: 0.1360
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0462 - mae: 0.1410
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0492 - mae: 0.1530
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0435 - mae: 0.1381
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0467 - mae: 0.1476
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0454 - mae: 0.1422
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0429 - mae: 0.1356
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0427 - mae: 0.1356
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0431 - mae: 0.1371
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0457 - mae: 0.1441
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0462 - mae: 0.1479

# %%
model_mlp.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │            96 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,925 (7.52 KB)
#  Trainable params: 641 (2.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,284 (5.02 KB)

# %%
# get_weights() retorna uma lista: o primeiro item é a matriz de pesos (W), o segundo é o viés (b)
pesos, vies = model_mlp.get_layer(index=0).get_weights()

print(f"pesos: {pesos.flatten()} e o viés: {vies[0]:.4f}")
# Out:
# pesos: [-0.24198203  0.59822977 -0.06502518  0.27549842 -0.11626412 -0.16439588
#   0.39772573  0.4480027  -0.28337356  0.13866319  0.07187331 -0.1478642
#  -0.13128707 -0.3733509  -0.24880603  0.19300805 -0.20298961  0.3866393
#  -0.3340086   0.2890147   0.30005845  0.10792243  0.15002353 -0.35990927
#  -0.05653777 -0.3028695  -0.26254135 -0.11717555 -0.25316456  0.5419782
#  -0.30015853  0.06257453  0.26373237  0.4644834   0.19109702  0.22582851
#   0.21588698 -0.31458595 -0.1494531   0.13168927  0.4205911   0.0718339
#  -0.08682622  0.31186444  0.09613959 -0.44731328  0.16791223  0.26860073
#  -0.20295165  0.3852917   0.05927976 -0.28170282 -0.09766156  0.34716144
#  -0.03761918  0.00404072 -0.02843626  0.3405204   0.3043777  -0.34034348
#   0.10293605  0.04242993  0.15703838 -0.08715234] e o viés: -0.5760

# %%
data_min = scaler.data_min_
scale = scaler.scale_

# w = pesos / scale (scale is the range: 1/(max - min))
w = pesos / scale[:, np.newaxis]
b_raw = vies - np.dot(data_min, w)

w_escalar = w[0][0]
b_raw_escalar = b_raw[0]

print(f"Pesos desnormalizados: {w.flatten()}")
print(f"Viés desnormalizado: {b_raw_escalar:.4f}")
# Out:
# Pesos desnormalizados: [-0.66494286  1.6438767  -0.17868282  0.75704265 -0.3194824  -0.45174375
#   1.0929112   1.2310674  -0.77868277  0.38103282  0.19750081 -0.40631628
#  -0.36076397 -1.0259316  -0.68369454  0.5303672  -0.5577955   1.0624468
#  -0.9178229   0.794184    0.8245312   0.29656026  0.41224995 -0.9889954
#  -0.15536025 -0.83225566 -0.7214379  -0.3219869  -0.6956714   1.4893029
#  -0.8248062   0.17194866  0.7247107   1.2763548   0.52511585  0.6205546
#   0.59323627 -0.86445135 -0.41068247  0.3618692   1.155743    0.19739251
#  -0.23858993  0.8569729   0.26418215 -1.229173    0.46140632  0.7380884
#  -0.5576912   1.0587437   0.16289496 -0.7740917  -0.2683644   0.9539656
#  -0.10337383  0.01110351 -0.07814006  0.9357167   0.8364001  -0.9352305
#   0.28285816  0.11659329  0.43152604 -0.23948608]
# Viés desnormalizado: -7.8693

# %%
plt.figure(figsize=(10, 5))

# Plotando a Perda (MSE)
plt.subplot(1, 2, 1)
plt.plot(historico.history['loss'], label='Erro Quadrático Médio (MSE)', color='red')
plt.title('Curva de Aprendizado - Loss')
plt.xlabel('Épocas')
plt.ylabel('MSE')
plt.legend()
plt.grid(True)

# Plotando a Métrica (MAE)
plt.subplot(1, 2, 2)
plt.plot(historico.history['mae'], label='Erro Médio Absoluto (MAE)', color='blue')
plt.title('Evolução da Métrica - MAE')
plt.xlabel('Épocas')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
erro_simples = model_mlp.evaluate(X_test_scaled, y_test, verbose=0)[1]
print(f"Erro Médio Absoluto (Simples): {erro_simples:.2f}\n")
# Out:
# Erro Médio Absoluto (Simples): 0.10

# %% [markdown]
# Valores Reais para testar previsões

# %%
plt.figure(figsize=(10, 6))
y_pred = model_mlp.predict(X_test_scaled)   
plt.plot(y_test, label='Valores Reais', marker='o')
plt.plot(y_pred, label='Previsões MLP', marker='x')
plt.title('Previsões vs Valores Reais - MLP')
plt.xlabel('Amostras de Teste')
plt.ylabel('Voltage')
plt.legend()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

current_input = X_test_scaled[0].copy().reshape(1, -1) 
recurrent_prediction = []
n_steps = 14

# Parâmetros do MinMaxScaler para a coluna 0 (shift_1)
min_voltagem = scaler.data_min_[0]
fator_escala = scaler.scale_[0]

for _ in range(n_steps):
    # Previsão da voltagem real
    next_pred = model_mlp.predict(current_input, verbose=0)[0][0]  
    recurrent_prediction.append(next_pred)  
    
    next_pred_scaled = (next_pred - min_voltagem) * fator_escala
    
    current_input = np.roll(current_input, shift=1, axis=1)  
    
    current_input[0, 0] = next_pred_scaled


y_true_50 = y_test[:n_steps].flatten()

mse = mean_squared_error(y_true_50, recurrent_prediction)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true_50, recurrent_prediction)

print(f"MSE:  {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}\n")

plt.figure(figsize=(10, 6))

plt.plot(y_true_50, label='Valores Reais', marker='o', color='dodgerblue', alpha=0.8)
plt.plot(recurrent_prediction, label='Previsões Recursivas MLP', marker='X', color='crimson', linestyle='--', alpha=0.9)

plt.title(f'Previsões Recursivas vs Valores Reais - MLP (Primeiros {n_steps} Passos)')
plt.xlabel('Passos de Tempo (Futuro)')
plt.ylabel('Voltage')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# MSE:  0.0393
# RMSE: 0.1983
# MAE:  0.1418
