# %% [markdown]
# ## Exploratory Analisys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import io

# %%
data = pd.read_csv('sensors.csv', sep = ',')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6928 entries, 0 to 6927
# Data columns (total 95 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 6927 non-null   object
#  1   Total Voltage (V)    6927 non-null   object
#  2   Average Voltage (V)  6927 non-null   float64
#  3   sensor 1             6927 non-null   float64
#  4   sensor 2             6927 non-null   float64
#  5   sensor 3             6927 non-null   float64
#  6   sensor 4             6927 non-null   float64
#  7   sensor 5             6927 non-null   float64
#  8   sensor 6             6927 non-null   float64
#  9   sensor 7             6927 non-null   float64
#  10  sensor 8             6927 non-null   float64
#  11  sensor 9             6927 non-null   float64
#  12  sensor 10            6927 non-null   float64
#  13  sensor 11            6927 non-null   float64
#  14  sensor 12            6927 non-null   float64
#  15  sensor 13            6927 non-null   float64
#  16  sensor 14            6927 non-null   float64
#  17  sensor 15            6927 non-null   float64
#  18  sensor 16            6927 non-null   float64
#  19  sensor 17            6927 non-null   float64
#  20  sensor 18            6927 non-null   float64
#  21  sensor 19            6927 non-null   float64
#  22  sensor 20            6927 non-null   float64
#  23  sensor 21            6927 non-null   float64
#  24  sensor 22            6927 non-null   float64
#  25  sensor 23            6927 non-null   float64
#  26  sensor 24            6927 non-null   float64
#  27  sensor 25            6927 non-null   float64
#  28  sensor 26            6927 non-null   float64
#  29  sensor 27            6927 non-null   float64
#  30  sensor 28            6927 non-null   float64
#  31  sensor 29            6927 non-null   float64
#  32  sensor 30            6927 non-null   float64
#  33  sensor 31            6927 non-null   float64
#  34  sensor 32            6927 non-null   float64
#  35  sensor 33            6927 non-null   float64
#  36  sensor 34            6927 non-null   float64
#  37  sensor 35            6927 non-null   float64
#  38  sensor 36            6927 non-null   float64
#  39  sensor 37            6927 non-null   float64
#  40  sensor 38            6927 non-null   float64
#  41  sensor 39            6927 non-null   float64
#  42  sensor 40            6927 non-null   float64
#  43  sensor 41            6927 non-null   float64
#  44  sensor 42            6927 non-null   float64
#  45  sensor 43            6927 non-null   float64
#  46  sensor 44            6927 non-null   float64
#  47  sensor 45            6927 non-null   float64
#  48  sensor 46            6927 non-null   float64
#  49  sensor 47            6927 non-null   float64
#  50  sensor 48            6927 non-null   float64
#  51  sensor 49            6927 non-null   float64
#  52  sensor 50            6927 non-null   float64
#  53  sensor 51            6927 non-null   float64
#  54  sensor 52            6927 non-null   float64
#  55  sensor 53            6927 non-null   float64
#  56  sensor 54            6927 non-null   float64
#  57  sensor 55            6927 non-null   float64
#  58  sensor 56            6927 non-null   float64
#  59  sensor 57            6927 non-null   float64
#  60  sensor 58            6927 non-null   float64
#  61  sensor 59            6927 non-null   float64
#  62  sensor 60            6927 non-null   float64
#  63  sensor 61            6927 non-null   float64
#  64  sensor 62            6927 non-null   float64
#  65  sensor 63            6927 non-null   float64
#  66  sensor 64            6927 non-null   float64
#  67  sensor 65            6927 non-null   float64
#  68  sensor 66            6927 non-null   float64
#  69  sensor 67            6927 non-null   float64
#  70  sensor 68            6927 non-null   float64
#  71  sensor 69            6927 non-null   float64
#  72  sensor 70            6927 non-null   float64
#  73  sensor 71            6927 non-null   float64
#  74  sensor 72            6927 non-null   float64
#  75  sensor 73            6927 non-null   float64
#  76  sensor 74            6927 non-null   float64
#  77  sensor 75            6927 non-null   float64
#  78  sensor 76            6927 non-null   float64
#  79  sensor 77            6927 non-null   float64
#  80  sensor 78            6927 non-null   float64
#  81  sensor 79            6927 non-null   float64
#  82  sensor 80            6927 non-null   float64
#  83  sensor 81            6927 non-null   float64
#  84  sensor 82            6927 non-null   float64
#  85  sensor 83            6927 non-null   float64
#  86  sensor 84            6927 non-null   float64
#  87  sensor 85            6927 non-null   float64
#  88  sensor 86            6927 non-null   float64
#  89  sensor 87            6927 non-null   float64
#  90  sensor 88            6927 non-null   float64
#  91  sensor 89            6927 non-null   float64
#  92  sensor 90            6927 non-null   float64
#  93  sensor 91            6927 non-null   float64
#  94  sensor 92            6927 non-null   float64
# dtypes: float64(93), object(2)
# memory usage: 5.0+ MB

# %%
#Dropping columns that are not relevant for the model  
data = data.drop(columns = ['Total Voltage (V)', 'Average Voltage (V)'])

#Converting the 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)


#Checking the first few rows of the updated dataset
data.head(3)
# Out:
#                  Date    sensor 1    sensor 2    sensor 3    sensor 4  \
# 0 2023-04-03 03:00:01  119.121812  115.827723  116.327884  117.658852
# 1 2023-04-03 04:00:01  121.092423  117.628034  118.118468  119.575351
# 2 2023-04-03 05:00:01  121.893561  118.410648  118.866724  120.405980
#
#      sensor 5    sensor 6    sensor 7    sensor 8    sensor 9  ...  \
# 0  117.589612  117.496657  115.859532  114.603809  118.058141  ...
# 1  119.504139  119.387818  117.598619  116.261870  119.998991  ...
# 2  120.332878  120.213393  118.315624  116.951690  120.807357  ...
#
#     sensor 83   sensor 84   sensor 85   sensor 86   sensor 87   sensor 88  \
# 0  115.647812  114.299245  116.471634  115.380364  115.110607  115.910664
# 1  117.329442  115.892439  118.243012  117.071528  116.750911  117.634598
# 2  118.087727  116.615680  119.053043  117.826122  117.492186  118.392878
#
#     sensor 89   sensor 90   sensor 91   sensor 92
# 0  117.049984  114.031306  113.770388  115.565692
# 1  118.956594  115.616289  115.338720  117.255179
# 2  119.695606  116.356843  116.066697  118.036934
#
# [3 rows x 93 columns]

# %% [markdown]
# The fig above show when the site shutdown, and thats it's not a good messure to bring to the model

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data = data, y='sensor 34', x='Date')
plt.title('Voltage Registred by Sensor 34')
plt.ylim(121.5, 130)
plt.xlabel('Date')
plt.ylabel('Voltage')
plt.show()

# %%
data = data[data['sensor 34'] > 121.5 ]
data['sensor 34'].describe()
# Out:
# count    6658.000000
# mean      123.555389
# std         0.805674
# min       121.585035
# 25%       122.852568
# 50%       123.424118
# 75%       124.263571
# max       125.811034
# Name: sensor 34, dtype: float64

# %%
average_s34 = data.groupby(data['Date'].dt.date)['sensor 34'].mean()
average_s34 = average_s34.reset_index()
average_s34.rename(columns={'Date': 'average_daily'}, inplace=True)
average_s34
# Out:
#     average_daily   sensor 34
# 0      2023-04-04  122.444449
# 1      2023-04-05  122.511457
# 2      2023-04-06  122.462247
# 3      2023-04-07  122.558795
# 4      2023-04-08  122.635337
# ..            ...         ...
# 301    2024-04-07  124.854037
# 302    2024-04-08  125.114604
# 303    2024-04-09  124.935289
# 304    2024-04-10  124.929781
# 305    2024-04-11  124.920366
#
# [306 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data = average_s34, x='average_daily', y='sensor 34')
plt.title('Voltage Registred by Sensor 34')
plt.ylim(121.5, 130)
plt.xlabel('Date')
plt.ylabel('Voltage')
plt.show()

# %%
average_s34['diff'] = average_s34['sensor 34'].diff()
average_s34.dropna(inplace=True)
average_s34.head(3)
# Out:
#   average_daily   sensor 34      diff
# 1    2023-04-05  122.511457  0.067008
# 2    2023-04-06  122.462247 -0.049210
# 3    2023-04-07  122.558795  0.096548

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
plot_acf(average_s34['sensor 34'], lags=30, ax=axes[0], alpha=0.05)
axes[0].set_title('Autocorrelação (ACF) - Sensor 34', fontsize=13)
axes[0].set_xlabel('Lags')
axes[0].set_ylabel('Correlação')
axes[0].grid(True, alpha=0.3)

plot_pacf(average_s34['sensor 34'], lags=30, method='yw', ax=axes[1], alpha=0.05)
axes[1].set_title('Autocorrelação Parcial (PACF) - Sensor 34', fontsize=13)
axes[1].set_xlabel('Lags')
axes[1].set_ylabel('Correlação Parcial')
axes[1].grid(True, alpha=0.3)

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
plot_acf(average_s34['diff'], lags=30, ax=axes[0], alpha=0.05)
axes[0].set_title('Autocorrelação (ACF) - Diff Sensor 34', fontsize=13)
axes[0].set_xlabel('Lags')
axes[0].set_ylabel('Correlação')
axes[0].grid(True, alpha=0.3)

plot_pacf(average_s34['diff'], lags=30, method='yw', ax=axes[1], alpha=0.05)
axes[1].set_title('Autocorrelação Parcial (PACF) - Diff Sensor 34', fontsize=13)
axes[1].set_xlabel('Lags')
axes[1].set_ylabel('Correlação Parcial')
axes[1].grid(True, alpha=0.3)

# %% [markdown]
# ## Features

# %% [markdown]
# Separating into test and training sets

# %%
for i in range(1, 3, 1):
        average_s34[f'shift_{i}'] = average_s34['sensor 34'].shift(i)
average_s34.dropna(inplace=True)

y = average_s34['sensor 34'].values.reshape(-1, 1).astype('float32')
X = average_s34[[f'shift_{i}' for i in range(1, 3)]].values.astype('float32')  # Usando os valores dos 8 dias anteriores como recursos


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False) #shuffle=False to maintain the time series order

# %%
preview = pd.DataFrame(X_train, columns=[f'shift_{i}' for i in range(1, 3)])
preview.head(3)
# Out:
#       shift_1     shift_2
# 0  122.462250  122.511459
# 1  122.558792  122.462250
# 2  122.635338  122.558792

# %%
X.shape, y.shape
# Out:
# ((303, 2), (303, 1))

# %% [markdown]
# Normalizando dados

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test) #Evitar datalake

# %% [markdown]
# Hiperparâmetros

# %%
TAXA_APRENDIZADO = 0.001  # Tamanho do "passo" na otimização (ex: 0.1, 0.01, 0.001)
EPOCAS = 200             # Quantas vezes a rede verá todo o dataset
TAMANHO_LOTE = 3     # Batch size 
tf.keras.utils.set_random_seed(42) # Garantir reprodutibilidade

# %% [markdown]
# Aplicando o treinamento

# %%
#Construção da arquitetura

#Camada de Entrada
model_mlp = Sequential([Dense(32, # 64 Neurônio nesta camada (Z = W*X + b)
                                  input_shape=(2,), # Quantidade de variáveis que vão entrar ( Z = w1*x1 + w2*x2 + b)
                                  activation='linear') ]) # Especificando qual vai ser o tipo de ativação. Ex: reLu, linear, tanh, sigmoid...


#Camada Oculta 1
model_mlp.add(Dense(16, activation='linear'))

#Camada de Saída
model_mlp.add(Dense(1, activation='linear')) # 1 Neurônio nesta camada (Z = W*X + b) --- IGNORE ---, ativação linear para regressão


#Configuração
model_mlp.compile(
    optimizer=Adam(learning_rate=TAXA_APRENDIZADO), #Aplicação do modelo de Gradiente descendente, usando o leanning rate proposto
    loss='mse', # Qual a função da loss. Nesse caso o mse é (Z - F(x1,x2))²
    metrics=['mae'] # Erro Médio Absoluto para termos uma métrica mais legível
)

#Treinamento
historico = model_mlp.fit(
    X_train_scaled, y_train, #Indica quais são as bases
    epochs=EPOCAS, batch_size=TAMANHO_LOTE, #O batch_size é a batelada de cada iteração (epoch) que será calculada
    shuffle=False, # Manter a ordem temporal dos dados
    verbose=1 # Mude para 1 se quiser ver o log de cada época
)
# Out:
# Epoch 1/200
# c:\Projeto de Manutenção\Maintenance-prediction\.venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 14651.1631 - mae: 121.0277
# Epoch 2/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11651.9863 - mae: 107.4412
# Epoch 3/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5466.0259 - mae: 68.8927
# Epoch 4/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1526.7618 - mae: 33.7365
# Epoch 5/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 905.4808 - mae: 27.0019
# Epoch 6/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 812.4195 - mae: 25.6119
# Epoch 7/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 742.5744 - mae: 24.4882
# Epoch 8/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 678.1620 - mae: 23.4026
# Epoch 9/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 618.1028 - mae: 22.3406
# Epoch 10/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 561.7330 - mae: 21.2953
# Epoch 11/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 508.6531 - mae: 20.2621
# Epoch 12/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 458.6080 - mae: 19.2355
# Epoch 13/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 411.4308 - mae: 18.2149
# Epoch 14/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 367.0151 - mae: 17.1992
# Epoch 15/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 325.2991 - mae: 16.1851
# Epoch 16/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 286.2537 - mae: 15.1743
# Epoch 17/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 249.8738 - mae: 14.1680
# Epoch 18/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 216.1703 - mae: 13.1688
# Epoch 19/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 185.1624 - mae: 12.1754
# Epoch 20/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 156.8699 - mae: 11.1930
# Epoch 21/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 131.3044 - mae: 10.2235
# Epoch 22/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 108.4613 - mae: 9.2735
# Epoch 23/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 88.3118 - mae: 8.3483
# Epoch 24/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 70.7942 - mae: 7.4529
# Epoch 25/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 55.8107 - mae: 6.5935
# Epoch 26/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 43.2222 - mae: 5.7768
# Epoch 27/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.8512 - mae: 5.0099
# Epoch 28/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 24.4853 - mae: 4.2984
# Epoch 29/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 17.8863 - mae: 3.6492
# Epoch 30/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12.8020 - mae: 3.0622
# Epoch 31/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9784 - mae: 2.5409
# Epoch 32/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.1728 - mae: 2.0864
# Epoch 33/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1643 - mae: 1.6976
# Epoch 34/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7608 - mae: 1.3693
# Epoch 35/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8028 - mae: 1.0961
# Epoch 36/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1634 - mae: 0.8720
# Epoch 37/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7454 - mae: 0.6928
# Epoch 38/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4774 - mae: 0.5492
# Epoch 39/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3086 - mae: 0.4361
# Epoch 40/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2038 - mae: 0.3493
# Epoch 41/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1398 - mae: 0.2838
# Epoch 42/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1011 - mae: 0.2351
# Epoch 43/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0780 - mae: 0.2002
# Epoch 44/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0643 - mae: 0.1755
# Epoch 45/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0562 - mae: 0.1584
# Epoch 46/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0515 - mae: 0.1484
# Epoch 47/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0488 - mae: 0.1425
# Epoch 48/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0472 - mae: 0.1386
# Epoch 49/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0463 - mae: 0.1368
# Epoch 50/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0458 - mae: 0.1356
# Epoch 51/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0455 - mae: 0.1352
# Epoch 52/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0453 - mae: 0.1355
# Epoch 53/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0452 - mae: 0.1357
# Epoch 54/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0451 - mae: 0.1360
# Epoch 55/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0451 - mae: 0.1362
# Epoch 56/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0450 - mae: 0.1364
# Epoch 57/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0450 - mae: 0.1367
# Epoch 58/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0449 - mae: 0.1369
# Epoch 59/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0449 - mae: 0.1372
# Epoch 60/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0448 - mae: 0.1374
# Epoch 61/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0448 - mae: 0.1377
# Epoch 62/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0448 - mae: 0.1380
# Epoch 63/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0447 - mae: 0.1383
# Epoch 64/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0447 - mae: 0.1385
# Epoch 65/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0447 - mae: 0.1388
# Epoch 66/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0447 - mae: 0.1391
# Epoch 67/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0447 - mae: 0.1395
# Epoch 68/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0447 - mae: 0.1397
# Epoch 69/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0447 - mae: 0.1401
# Epoch 70/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0448 - mae: 0.1405
# Epoch 71/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0449 - mae: 0.1410
# Epoch 72/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0450 - mae: 0.1416
# Epoch 73/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0451 - mae: 0.1423
# Epoch 74/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0453 - mae: 0.1431
# Epoch 75/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0455 - mae: 0.1440
# Epoch 76/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0457 - mae: 0.1450
# Epoch 77/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0460 - mae: 0.1461
# Epoch 78/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0463 - mae: 0.1473
# Epoch 79/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0467 - mae: 0.1487
# Epoch 80/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0472 - mae: 0.1503
# Epoch 81/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0477 - mae: 0.1522
# Epoch 82/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0484 - mae: 0.1544
# Epoch 83/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0491 - mae: 0.1566
# Epoch 84/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0501 - mae: 0.1593
# Epoch 85/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0512 - mae: 0.1624
# Epoch 86/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0525 - mae: 0.1659
# Epoch 87/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0541 - mae: 0.1694
# Epoch 88/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0559 - mae: 0.1731
# Epoch 89/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0578 - mae: 0.1771
# Epoch 90/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0599 - mae: 0.1810
# Epoch 91/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0621 - mae: 0.1846
# Epoch 92/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0644 - mae: 0.1881
# Epoch 93/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0665 - mae: 0.1914
# Epoch 94/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0684 - mae: 0.1946
# Epoch 95/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0701 - mae: 0.1972
# Epoch 96/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0715 - mae: 0.1992
# Epoch 97/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0728 - mae: 0.2008
# Epoch 98/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0738 - mae: 0.2018
# Epoch 99/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0747 - mae: 0.2021
# Epoch 100/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0755 - mae: 0.2020
# Epoch 101/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0762 - mae: 0.2015
# Epoch 102/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0767 - mae: 0.2014
# Epoch 103/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0769 - mae: 0.2011
# Epoch 104/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0767 - mae: 0.2007
# Epoch 105/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0761 - mae: 0.1998
# Epoch 106/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0750 - mae: 0.1986
# Epoch 107/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0736 - mae: 0.1967
# Epoch 108/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0720 - mae: 0.1943
# Epoch 109/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0703 - mae: 0.1915
# Epoch 110/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0685 - mae: 0.1886
# Epoch 111/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0668 - mae: 0.1863
# Epoch 112/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0652 - mae: 0.1840
# Epoch 113/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0637 - mae: 0.1817
# Epoch 114/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0624 - mae: 0.1797
# Epoch 115/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0613 - mae: 0.1783
# Epoch 116/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0605 - mae: 0.1770
# Epoch 117/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0599 - mae: 0.1765
# Epoch 118/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0596 - mae: 0.1764
# Epoch 119/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0596 - mae: 0.1767
# Epoch 120/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0599 - mae: 0.1774
# Epoch 121/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0606 - mae: 0.1784
# Epoch 122/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0616 - mae: 0.1801
# Epoch 123/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0629 - mae: 0.1826
# Epoch 124/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0647 - mae: 0.1862
# Epoch 125/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0669 - mae: 0.1905
# Epoch 126/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0695 - mae: 0.1954
# Epoch 127/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0725 - mae: 0.2010
# Epoch 128/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0757 - mae: 0.2072
# Epoch 129/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0790 - mae: 0.2136
# Epoch 130/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0824 - mae: 0.2196
# Epoch 131/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0856 - mae: 0.2251
# Epoch 132/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0885 - mae: 0.2300
# Epoch 133/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0910 - mae: 0.2340
# Epoch 134/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0932 - mae: 0.2373
# Epoch 135/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0949 - mae: 0.2401
# Epoch 136/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0963 - mae: 0.2423
# Epoch 137/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0974 - mae: 0.2440
# Epoch 138/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0982 - mae: 0.2453
# Epoch 139/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0989 - mae: 0.2463
# Epoch 140/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0994 - mae: 0.2471
# Epoch 141/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0999 - mae: 0.2477
# Epoch 142/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1002 - mae: 0.2482
# Epoch 143/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1005 - mae: 0.2487
# Epoch 144/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1007 - mae: 0.2490
# Epoch 145/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1009 - mae: 0.2493
# Epoch 146/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1010 - mae: 0.2495
# Epoch 147/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1011 - mae: 0.2497
# Epoch 148/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1012 - mae: 0.2499
# Epoch 149/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1013 - mae: 0.2500
# Epoch 150/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1014 - mae: 0.2501
# Epoch 151/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1014 - mae: 0.2502
# Epoch 152/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1015 - mae: 0.2503
# Epoch 153/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1015 - mae: 0.2503
# Epoch 154/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1016 - mae: 0.2504
# Epoch 155/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1016 - mae: 0.2504
# Epoch 156/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1016 - mae: 0.2505
# Epoch 157/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1016 - mae: 0.2505
# Epoch 158/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1017 - mae: 0.2505
# Epoch 159/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1017 - mae: 0.2506
# Epoch 160/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1017 - mae: 0.2506
# Epoch 161/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1017 - mae: 0.2506
# Epoch 162/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1017 - mae: 0.2506
# Epoch 163/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1017 - mae: 0.2506
# Epoch 164/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1017 - mae: 0.2506
# Epoch 165/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1017 - mae: 0.2506
# Epoch 166/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1017 - mae: 0.2506
# Epoch 167/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 168/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 169/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 170/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 171/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 172/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 173/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 174/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 175/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 176/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 177/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 178/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 179/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 180/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 181/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 182/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 183/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 184/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 185/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 186/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 187/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 188/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 189/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 190/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 191/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 192/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 193/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 194/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 195/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 196/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 197/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 198/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2507
# Epoch 199/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2506
# Epoch 200/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - mae: 0.2506

# %%
model_mlp.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_24 (Dense)                │ (None, 32)             │            96 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,925 (7.52 KB)
#  Trainable params: 641 (2.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,284 (5.02 KB)

# %%
# get_weights() retorna uma lista: o primeiro item é a matriz de pesos (W), o segundo é o viés (b)
pesos, vies = model_mlp.get_layer(index=0).get_weights()

print(f"pesos: {pesos.flatten()} e o viés: {vies[0]:.4f}")
# Out:
# pesos: [ 2.5296107e-01  1.7480887e-01 -2.5498912e-01  4.3744099e-01
#  -3.1968752e-01  6.8931147e-02  1.9741985e-01 -2.3443760e-01
#   3.3753476e-01  1.5567577e-01 -3.1719920e-01  5.8696503e-03
#   3.4133986e-01 -8.3063334e-02 -2.6111703e-02  2.5832710e-01
#  -3.6806104e-01 -2.9449776e-01 -4.7537759e-02 -2.8398672e-01
#  -3.2071397e-01  3.4401938e-01  3.1484234e-01 -2.4359785e-01
#   2.7641204e-01 -2.8619212e-01  4.9809017e-04 -1.2187660e-01
#   2.7312679e-02 -1.9365980e-01 -2.1543854e-01  3.9757955e-01
#  -3.6695093e-01 -1.8412685e-02 -3.2253161e-01 -2.6764965e-01
#   2.2248891e-01 -3.1664464e-01 -3.7858665e-02  1.6268845e-01
#  -7.6955400e-02  8.9844041e-02 -1.1626818e-01 -5.2349452e-02
#   3.3816591e-01 -1.2437832e-01  6.3260482e-03 -1.7927298e-01
#  -2.8729212e-01  1.5442245e-01  4.6596818e-02  7.9127476e-02
#  -3.3542925e-01 -2.7645683e-01  2.1750963e-01  2.7178374e-01
#  -7.4984528e-02 -1.3694954e-01 -3.6746335e-01 -5.5021864e-01
#   1.9676991e-01  3.2555440e-01 -8.3411656e-02  1.7807080e-01] e o viés: 0.6727

# %%
data_min = scaler.data_min_
scale = scaler.scale_

# w = pesos / scale (scale is the range: 1/(max - min))
w = pesos / scale[:, np.newaxis]
b_raw = vies - np.dot(data_min, w)

w_escalar = w[0][0]
b_raw_escalar = b_raw[0]

print(f"Pesos desnormalizados: {w.flatten()}")
print(f"Viés desnormalizado: {b_raw_escalar:.4f}")
# Out:
# Pesos desnormalizados: [ 6.9511217e-01  4.8035765e-01 -7.0068508e-01  1.2020450e+00
#  -8.7846994e-01  1.8941604e-01  5.4249036e-01 -6.4421153e-01
#   9.2751241e-01  4.2778173e-01 -8.7163228e-01  1.6129224e-02
#   9.3796843e-01 -2.2824989e-01 -7.1752399e-02  7.0985752e-01
#  -1.0113956e+00 -8.0925095e-01 -1.3062909e-01 -7.8036761e-01
#  -8.8129050e-01  9.4533151e-01  8.6515588e-01 -6.6938299e-01
#   7.5955313e-01 -7.8642786e-01  1.3687030e-03 -3.3490494e-01
#   7.5052559e-02 -5.3215814e-01 -5.9200400e-01  1.0925096e+00
#  -1.0083451e+00 -5.0596252e-02 -8.8628525e-01 -7.3547500e-01
#   6.1137772e-01 -8.7010843e-01 -1.0403190e-01  4.4705188e-01
#  -2.1146590e-01  2.4688260e-01 -3.1949356e-01 -1.4385116e-01
#   9.2924672e-01 -3.4177944e-01  1.7383359e-02 -4.9262455e-01
#  -7.8945059e-01  4.2433774e-01  1.2804349e-01  2.1743454e-01
#  -9.2172664e-01 -7.5967628e-01  5.9769511e-01  7.4683505e-01
#  -2.0605013e-01 -3.7632391e-01 -1.0097532e+00 -1.5119468e+00
#   5.4070443e-01  8.9459157e-01 -2.2920705e-01  4.8932108e-01]
# Viés desnormalizado: 38.8954

# %%
plt.figure(figsize=(10, 5))

# Plotando a Perda (MSE)
plt.subplot(1, 2, 1)
plt.plot(historico.history['loss'], label='Erro Quadrático Médio (MSE)', color='red')
plt.title('Curva de Aprendizado - Loss')
plt.xlabel('Épocas')
plt.ylabel('MSE')
plt.legend()
plt.grid(True)

# Plotando a Métrica (MAE)
plt.subplot(1, 2, 2)
plt.plot(historico.history['mae'], label='Erro Médio Absoluto (MAE)', color='blue')
plt.title('Evolução da Métrica - MAE')
plt.xlabel('Épocas')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
erro_simples = model_mlp.evaluate(X_test_scaled, y_test, verbose=0)[1]
print(f"Erro Médio Absoluto (Simples): {erro_simples:.2f}\n")
# Out:
# Erro Médio Absoluto (Simples): 0.15

# %% [markdown]
# Valores Reais para testar previsões

# %%
plt.figure(figsize=(10, 6))
y_pred = model_mlp.predict(X_test_scaled)   
plt.plot(y_test, label='Valores Reais', marker='o')
plt.plot(y_pred, label='Previsões MLP', marker='x')
plt.title('Previsões vs Valores Reais - MLP')
plt.xlabel('Amostras de Teste')
plt.ylabel('Voltage')
plt.legend()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

current_input = X_test_scaled[0].copy().reshape(1, -1) 
recurrent_prediction = []
n_steps = 14

# Parâmetros do MinMaxScaler para a coluna 0 (shift_1)
min_voltagem = scaler.data_min_[0]
fator_escala = scaler.scale_[0]

for _ in range(n_steps):
    # Previsão da voltagem real
    next_pred = model_mlp.predict(current_input, verbose=0)[0][0]  
    recurrent_prediction.append(next_pred)  
    
    next_pred_scaled = (next_pred - min_voltagem) * fator_escala
    
    current_input = np.roll(current_input, shift=1, axis=1)  
    
    current_input[0, 0] = next_pred_scaled


y_true_50 = y_test[:n_steps].flatten()

mse = mean_squared_error(y_true_50, recurrent_prediction)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true_50, recurrent_prediction)

print(f"MSE:  {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}\n")

plt.figure(figsize=(10, 6))

plt.plot(y_true_50, label='Valores Reais', marker='o', color='dodgerblue', alpha=0.8)
plt.plot(recurrent_prediction, label='Previsões Recursivas MLP', marker='X', color='crimson', linestyle='--', alpha=0.9)

plt.title(f'Previsões Recursivas vs Valores Reais - MLP (Primeiros {n_steps} Passos)')
plt.xlabel('Passos de Tempo (Futuro)')
plt.ylabel('Voltage')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# MSE:  0.0618
# RMSE: 0.2485
# MAE:  0.1767
