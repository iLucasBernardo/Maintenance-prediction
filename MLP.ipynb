# %% [markdown]
# ## Exploratory Analisys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import io

# %%
data = pd.read_csv('sensors.csv', sep = ',')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6928 entries, 0 to 6927
# Data columns (total 95 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 6927 non-null   object
#  1   Total Voltage (V)    6927 non-null   object
#  2   Average Voltage (V)  6927 non-null   float64
#  3   sensor 1             6927 non-null   float64
#  4   sensor 2             6927 non-null   float64
#  5   sensor 3             6927 non-null   float64
#  6   sensor 4             6927 non-null   float64
#  7   sensor 5             6927 non-null   float64
#  8   sensor 6             6927 non-null   float64
#  9   sensor 7             6927 non-null   float64
#  10  sensor 8             6927 non-null   float64
#  11  sensor 9             6927 non-null   float64
#  12  sensor 10            6927 non-null   float64
#  13  sensor 11            6927 non-null   float64
#  14  sensor 12            6927 non-null   float64
#  15  sensor 13            6927 non-null   float64
#  16  sensor 14            6927 non-null   float64
#  17  sensor 15            6927 non-null   float64
#  18  sensor 16            6927 non-null   float64
#  19  sensor 17            6927 non-null   float64
#  20  sensor 18            6927 non-null   float64
#  21  sensor 19            6927 non-null   float64
#  22  sensor 20            6927 non-null   float64
#  23  sensor 21            6927 non-null   float64
#  24  sensor 22            6927 non-null   float64
#  25  sensor 23            6927 non-null   float64
#  26  sensor 24            6927 non-null   float64
#  27  sensor 25            6927 non-null   float64
#  28  sensor 26            6927 non-null   float64
#  29  sensor 27            6927 non-null   float64
#  30  sensor 28            6927 non-null   float64
#  31  sensor 29            6927 non-null   float64
#  32  sensor 30            6927 non-null   float64
#  33  sensor 31            6927 non-null   float64
#  34  sensor 32            6927 non-null   float64
#  35  sensor 33            6927 non-null   float64
#  36  sensor 34            6927 non-null   float64
#  37  sensor 35            6927 non-null   float64
#  38  sensor 36            6927 non-null   float64
#  39  sensor 37            6927 non-null   float64
#  40  sensor 38            6927 non-null   float64
#  41  sensor 39            6927 non-null   float64
#  42  sensor 40            6927 non-null   float64
#  43  sensor 41            6927 non-null   float64
#  44  sensor 42            6927 non-null   float64
#  45  sensor 43            6927 non-null   float64
#  46  sensor 44            6927 non-null   float64
#  47  sensor 45            6927 non-null   float64
#  48  sensor 46            6927 non-null   float64
#  49  sensor 47            6927 non-null   float64
#  50  sensor 48            6927 non-null   float64
#  51  sensor 49            6927 non-null   float64
#  52  sensor 50            6927 non-null   float64
#  53  sensor 51            6927 non-null   float64
#  54  sensor 52            6927 non-null   float64
#  55  sensor 53            6927 non-null   float64
#  56  sensor 54            6927 non-null   float64
#  57  sensor 55            6927 non-null   float64
#  58  sensor 56            6927 non-null   float64
#  59  sensor 57            6927 non-null   float64
#  60  sensor 58            6927 non-null   float64
#  61  sensor 59            6927 non-null   float64
#  62  sensor 60            6927 non-null   float64
#  63  sensor 61            6927 non-null   float64
#  64  sensor 62            6927 non-null   float64
#  65  sensor 63            6927 non-null   float64
#  66  sensor 64            6927 non-null   float64
#  67  sensor 65            6927 non-null   float64
#  68  sensor 66            6927 non-null   float64
#  69  sensor 67            6927 non-null   float64
#  70  sensor 68            6927 non-null   float64
#  71  sensor 69            6927 non-null   float64
#  72  sensor 70            6927 non-null   float64
#  73  sensor 71            6927 non-null   float64
#  74  sensor 72            6927 non-null   float64
#  75  sensor 73            6927 non-null   float64
#  76  sensor 74            6927 non-null   float64
#  77  sensor 75            6927 non-null   float64
#  78  sensor 76            6927 non-null   float64
#  79  sensor 77            6927 non-null   float64
#  80  sensor 78            6927 non-null   float64
#  81  sensor 79            6927 non-null   float64
#  82  sensor 80            6927 non-null   float64
#  83  sensor 81            6927 non-null   float64
#  84  sensor 82            6927 non-null   float64
#  85  sensor 83            6927 non-null   float64
#  86  sensor 84            6927 non-null   float64
#  87  sensor 85            6927 non-null   float64
#  88  sensor 86            6927 non-null   float64
#  89  sensor 87            6927 non-null   float64
#  90  sensor 88            6927 non-null   float64
#  91  sensor 89            6927 non-null   float64
#  92  sensor 90            6927 non-null   float64
#  93  sensor 91            6927 non-null   float64
#  94  sensor 92            6927 non-null   float64
# dtypes: float64(93), object(2)
# memory usage: 5.0+ MB

# %%
#Dropping columns that are not relevant for the model  
data = data.drop(columns = ['Total Voltage (V)', 'Average Voltage (V)'])

#Converting the 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)


#Checking the first few rows of the updated dataset
data.head(3)
# Out:
#                  Date    sensor 1    sensor 2    sensor 3    sensor 4  \
# 0 2023-04-03 03:00:01  119.121812  115.827723  116.327884  117.658852
# 1 2023-04-03 04:00:01  121.092423  117.628034  118.118468  119.575351
# 2 2023-04-03 05:00:01  121.893561  118.410648  118.866724  120.405980
#
#      sensor 5    sensor 6    sensor 7    sensor 8    sensor 9  ...  \
# 0  117.589612  117.496657  115.859532  114.603809  118.058141  ...
# 1  119.504139  119.387818  117.598619  116.261870  119.998991  ...
# 2  120.332878  120.213393  118.315624  116.951690  120.807357  ...
#
#     sensor 83   sensor 84   sensor 85   sensor 86   sensor 87   sensor 88  \
# 0  115.647812  114.299245  116.471634  115.380364  115.110607  115.910664
# 1  117.329442  115.892439  118.243012  117.071528  116.750911  117.634598
# 2  118.087727  116.615680  119.053043  117.826122  117.492186  118.392878
#
#     sensor 89   sensor 90   sensor 91   sensor 92
# 0  117.049984  114.031306  113.770388  115.565692
# 1  118.956594  115.616289  115.338720  117.255179
# 2  119.695606  116.356843  116.066697  118.036934
#
# [3 rows x 93 columns]

# %% [markdown]
# The fig above show when the site shutdown, and thats it's not a good messure to bring to the model

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data = data, y='sensor 34', x='Date')
plt.title('Voltage Registred by Sensor 34')
plt.ylim(121.5, 130)
plt.xlabel('Date')
plt.ylabel('Voltage')
plt.show()

# %%
data = data[data['sensor 34'] > 121.5 ]
data['sensor 34'].describe()
# Out:
# count    6658.000000
# mean      123.555389
# std         0.805674
# min       121.585035
# 25%       122.852568
# 50%       123.424118
# 75%       124.263571
# max       125.811034
# Name: sensor 34, dtype: float64

# %%
average_s34 = data.groupby(data['Date'].dt.date)['sensor 34'].mean()
average_s34 = average_s34.reset_index()
average_s34.rename(columns={'Date': 'average_daily'}, inplace=True)
average_s34
# Out:
#     average_daily   sensor 34
# 0      2023-04-04  122.444449
# 1      2023-04-05  122.511457
# 2      2023-04-06  122.462247
# 3      2023-04-07  122.558795
# 4      2023-04-08  122.635337
# ..            ...         ...
# 301    2024-04-07  124.854037
# 302    2024-04-08  125.114604
# 303    2024-04-09  124.935289
# 304    2024-04-10  124.929781
# 305    2024-04-11  124.920366
#
# [306 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data = average_s34, x='average_daily', y='sensor 34')
plt.title('Voltage Registred by Sensor 34')
plt.ylim(121.5, 130)
plt.xlabel('Date')
plt.ylabel('Voltage')
plt.show()

# %%
average_s34['diff'] = average_s34['sensor 34'].diff()
average_s34.dropna(inplace=True)
average_s34.head(3)
# Out:
#   average_daily   sensor 34      diff
# 1    2023-04-05  122.511457  0.067008
# 2    2023-04-06  122.462247 -0.049210
# 3    2023-04-07  122.558795  0.096548

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
plot_acf(average_s34['sensor 34'], lags=30, ax=axes[0], alpha=0.05)
axes[0].set_title('Autocorrelação (ACF) - Sensor 34', fontsize=13)
axes[0].set_xlabel('Lags')
axes[0].set_ylabel('Correlação')
axes[0].grid(True, alpha=0.3)

plot_pacf(average_s34['sensor 34'], lags=30, method='yw', ax=axes[1], alpha=0.05)
axes[1].set_title('Autocorrelação Parcial (PACF) - Sensor 34', fontsize=13)
axes[1].set_xlabel('Lags')
axes[1].set_ylabel('Correlação Parcial')
axes[1].grid(True, alpha=0.3)

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
plot_acf(average_s34['diff'], lags=30, ax=axes[0], alpha=0.05)
axes[0].set_title('Autocorrelação (ACF) - Diff Sensor 34', fontsize=13)
axes[0].set_xlabel('Lags')
axes[0].set_ylabel('Correlação')
axes[0].grid(True, alpha=0.3)

plot_pacf(average_s34['diff'], lags=30, method='yw', ax=axes[1], alpha=0.05)
axes[1].set_title('Autocorrelação Parcial (PACF) - Diff Sensor 34', fontsize=13)
axes[1].set_xlabel('Lags')
axes[1].set_ylabel('Correlação Parcial')
axes[1].grid(True, alpha=0.3)

# %% [markdown]
# ## Features

# %% [markdown]
# Separating into test and training sets

# %%
for i in range(1, 13, 1):
        average_s34[f'shift_{i}'] = average_s34['sensor 34'].shift(i)
average_s34.dropna(inplace=True)

y = average_s34['sensor 34'].values.reshape(-1, 1).astype('float32')
X = average_s34[[f'shift_{i}' for i in range(1, 13)]].values.astype('float32')  # Usando os valores dos 8 dias anteriores como recursos


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False) #shuffle=False to maintain the time series order

# %%
preview = pd.DataFrame(X_train, columns=[f'shift_{i}' for i in range(1, 13)])
preview.head(3)
# Out:
#       shift_1     shift_2     shift_3     shift_4     shift_5     shift_6  \
# 0  122.652016  122.672432  122.894722  122.710663  122.669357  122.802719
# 1  122.482727  122.652016  122.672432  122.894722  122.710663  122.669357
# 2  122.620331  122.482727  122.652016  122.672432  122.894722  122.710663
#
#       shift_7     shift_8     shift_9    shift_10    shift_11    shift_12
# 0  122.763039  122.916603  122.530319  122.479309  122.377426  122.505692
# 1  122.802719  122.763039  122.916603  122.530319  122.479309  122.377426
# 2  122.669357  122.802719  122.763039  122.916603  122.530319  122.479309

# %%
X.shape, y.shape
# Out:
# ((289, 12), (289, 1))

# %% [markdown]
# Normalizando dados

# %%
#scaler = StandardScaler()
#X_train_scaled = scaler.fit_transform(X_train)
#X_test_scaled = scaler.transform(X_test) #Evitar datalake



scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test) #Evitar datalake

# %% [markdown]
# Hiperparâmetros

# %%
TAXA_APRENDIZADO = 0.001  # Tamanho do "passo" na otimização (ex: 0.1, 0.01, 0.001)
EPOCAS = 300             # Quantas vezes a rede verá todo o dataset
TAMANHO_LOTE = 10         # Batch size

# %% [markdown]
# Aplicando o treinamento

# %%
#Construção da arquitetura

#Camada de Entrada
model_mlp = Sequential([Dense(120, # 64 Neurônio nesta camada (Z = W*X + b)
                                  input_shape=(12,), # Quantidade de variáveis que vão entrar ( Z = w1*x1 + w2*x2 + b)
                                  activation='relu') ]) # Especificando qual vai ser o tipo de ativação. Ex: reLu, linear, tanh, sigmoid...


#Camada Oculta 1
model_mlp.add(Dense(60, activation='relu'))

#Camada de Saída
model_mlp.add(Dense(1, activation='linear')) # 1 Neurônio nesta camada (Z = W*X + b) --- IGNORE ---, ativação linear para regressão


#Configuração
model_mlp.compile(
    optimizer=Adam(learning_rate=TAXA_APRENDIZADO), #Aplicação do modelo de Gradiente descendente, usando o leanning rate proposto
    loss='mse', # Qual a função da loss. Nesse caso o mse é (Z - F(x1,x2))²
    metrics=['mae'] # Erro Médio Absoluto para termos uma métrica mais legível
)

#Treinamento
historico = model_mlp.fit(
    X_train_scaled, y_train, #Indica quais são as bases
    epochs=EPOCAS, batch_size=TAMANHO_LOTE, #O batch_size é a batelada de cada iteração (epoch) que será calculada
    verbose=1 # Mude para 1 se quiser ver o log de cada época
)
# Out:
# Epoch 1/300
# c:\Projeto de Manutenção\Maintenance-prediction\.venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15026.5898 - mae: 122.5810
# Epoch 2/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14232.5293 - mae: 119.2863
# Epoch 3/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12228.1260 - mae: 110.4381
# Epoch 4/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8385.5068 - mae: 90.5426
# Epoch 5/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3925.1829 - mae: 57.3193
# Epoch 6/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1859.1353 - mae: 38.1187
# Epoch 7/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1711.0511 - mae: 36.8705
# Epoch 8/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1674.6289 - mae: 36.4836
# Epoch 9/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1621.3302 - mae: 35.9218
# Epoch 10/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1574.8705 - mae: 35.4101
# Epoch 11/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1514.7126 - mae: 34.6959
# Epoch 12/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1463.4525 - mae: 34.1313
# Epoch 13/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1409.9290 - mae: 33.4401
# Epoch 14/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1372.5288 - mae: 32.9759
# Epoch 15/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1253.8079 - mae: 31.5351
# Epoch 16/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1192.1803 - mae: 30.7388
# Epoch 17/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1109.5538 - mae: 29.6782
# Epoch 18/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1028.7925 - mae: 28.6108
# Epoch 19/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 959.0488 - mae: 27.5626
# Epoch 20/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 869.8971 - mae: 26.2432
# Epoch 21/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 789.2234 - mae: 25.0566
# Epoch 22/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 701.1727 - mae: 23.5443
# Epoch 23/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 633.7692 - mae: 22.4331
# Epoch 24/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 549.9933 - mae: 20.8215
# Epoch 25/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 460.6754 - mae: 19.1023
# Epoch 26/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 394.7292 - mae: 17.7071
# Epoch 27/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 329.8279 - mae: 16.1370
# Epoch 28/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 265.4935 - mae: 14.5223
# Epoch 29/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 218.1399 - mae: 13.1063
# Epoch 30/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 169.3534 - mae: 11.6220
# Epoch 31/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 130.1431 - mae: 10.1562
# Epoch 32/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 99.1275 - mae: 8.8380
# Epoch 33/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 74.1873 - mae: 7.6373
# Epoch 34/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 55.0519 - mae: 6.5774
# Epoch 35/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.3858 - mae: 5.5593
# Epoch 36/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.6341 - mae: 4.6536
# Epoch 37/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.3634 - mae: 3.8818
# Epoch 38/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.0390 - mae: 3.1669
# Epoch 39/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0922 - mae: 2.6610
# Epoch 40/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7579 - mae: 2.1152
# Epoch 41/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5413 - mae: 1.6462
# Epoch 42/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3855 - mae: 1.3194
# Epoch 43/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6069 - mae: 1.0965
# Epoch 44/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0707 - mae: 0.8657
# Epoch 45/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7354 - mae: 0.7083
# Epoch 46/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5574 - mae: 0.6027
# Epoch 47/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4275 - mae: 0.5136
# Epoch 48/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3663 - mae: 0.4647
# Epoch 49/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3119 - mae: 0.4174
# Epoch 50/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2807 - mae: 0.3950
# Epoch 51/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2812 - mae: 0.3899
# Epoch 52/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2490 - mae: 0.3696
# Epoch 53/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2330 - mae: 0.3545
# Epoch 54/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2332 - mae: 0.3536
# Epoch 55/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2200 - mae: 0.3433
# Epoch 56/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2145 - mae: 0.3375
# Epoch 57/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2044 - mae: 0.3357
# Epoch 58/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1940 - mae: 0.3239
# Epoch 59/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1931 - mae: 0.3181
# Epoch 60/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1891 - mae: 0.3150
# Epoch 61/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1815 - mae: 0.3086
# Epoch 62/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1836 - mae: 0.3102
# Epoch 63/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1816 - mae: 0.3078
# Epoch 64/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1704 - mae: 0.2981
# Epoch 65/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1715 - mae: 0.3061
# Epoch 66/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1608 - mae: 0.2867
# Epoch 67/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1566 - mae: 0.2868
# Epoch 68/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1529 - mae: 0.2802
# Epoch 69/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1476 - mae: 0.2757
# Epoch 70/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1479 - mae: 0.2783
# Epoch 71/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1530 - mae: 0.2810
# Epoch 72/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1433 - mae: 0.2711
# Epoch 73/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1454 - mae: 0.2859
# Epoch 74/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1353 - mae: 0.2634
# Epoch 75/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1498 - mae: 0.2742
# Epoch 76/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1369 - mae: 0.2714
# Epoch 77/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1323 - mae: 0.2601
# Epoch 78/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1294 - mae: 0.2584
# Epoch 79/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1391 - mae: 0.2692
# Epoch 80/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1172 - mae: 0.2460
# Epoch 81/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1200 - mae: 0.2472
# Epoch 82/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1279 - mae: 0.2616
# Epoch 83/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1251 - mae: 0.2581
# Epoch 84/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1166 - mae: 0.2381
# Epoch 85/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1148 - mae: 0.2450
# Epoch 86/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1108 - mae: 0.2339
# Epoch 87/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1078 - mae: 0.2330
# Epoch 88/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1100 - mae: 0.2334
# Epoch 89/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1043 - mae: 0.2252
# Epoch 90/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1029 - mae: 0.2278
# Epoch 91/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1006 - mae: 0.2237
# Epoch 92/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1034 - mae: 0.2276
# Epoch 93/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0954 - mae: 0.2200
# Epoch 94/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0964 - mae: 0.2144
# Epoch 95/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0995 - mae: 0.2205
# Epoch 96/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0995 - mae: 0.2247
# Epoch 97/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0964 - mae: 0.2208
# Epoch 98/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0875 - mae: 0.2068
# Epoch 99/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0997 - mae: 0.2228
# Epoch 100/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0897 - mae: 0.2110
# Epoch 101/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0834 - mae: 0.2035
# Epoch 102/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0833 - mae: 0.2031
# Epoch 103/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0807 - mae: 0.1993
# Epoch 104/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0813 - mae: 0.1979
# Epoch 105/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0801 - mae: 0.1990
# Epoch 106/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0774 - mae: 0.1954
# Epoch 107/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0757 - mae: 0.1943
# Epoch 108/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0743 - mae: 0.1904
# Epoch 109/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0746 - mae: 0.1952
# Epoch 110/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0760 - mae: 0.1933
# Epoch 111/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0741 - mae: 0.1892
# Epoch 112/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0735 - mae: 0.1922
# Epoch 113/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0736 - mae: 0.1907
# Epoch 114/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0688 - mae: 0.1824
# Epoch 115/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0822 - mae: 0.2045
# Epoch 116/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0658 - mae: 0.1793
# Epoch 117/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0681 - mae: 0.1816
# Epoch 118/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0664 - mae: 0.1835
# Epoch 119/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0721 - mae: 0.1929
# Epoch 120/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0625 - mae: 0.1826
# Epoch 121/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0601 - mae: 0.1734
# Epoch 122/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0630 - mae: 0.1821
# Epoch 123/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0629 - mae: 0.1786
# Epoch 124/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0595 - mae: 0.1752
# Epoch 125/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0631 - mae: 0.1768
# Epoch 126/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0579 - mae: 0.1670
# Epoch 127/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0603 - mae: 0.1744
# Epoch 128/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0586 - mae: 0.1679
# Epoch 129/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0559 - mae: 0.1655
# Epoch 130/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0554 - mae: 0.1626
# Epoch 131/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0563 - mae: 0.1702
# Epoch 132/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0547 - mae: 0.1616
# Epoch 133/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0526 - mae: 0.1589
# Epoch 134/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0600 - mae: 0.1719
# Epoch 135/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0530 - mae: 0.1616
# Epoch 136/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0521 - mae: 0.1605
# Epoch 137/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0514 - mae: 0.1554
# Epoch 138/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0513 - mae: 0.1636
# Epoch 139/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0546 - mae: 0.1666
# Epoch 140/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0521 - mae: 0.1610
# Epoch 141/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0548 - mae: 0.1706
# Epoch 142/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0494 - mae: 0.1572
# Epoch 143/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0603 - mae: 0.1784
# Epoch 144/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0546 - mae: 0.1617
# Epoch 145/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0503 - mae: 0.1597
# Epoch 146/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0588 - mae: 0.1842
# Epoch 147/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0529 - mae: 0.1645
# Epoch 148/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0468 - mae: 0.1466
# Epoch 149/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0465 - mae: 0.1461
# Epoch 150/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0478 - mae: 0.1568
# Epoch 151/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0512 - mae: 0.1602
# Epoch 152/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0469 - mae: 0.1455
# Epoch 153/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0483 - mae: 0.1490
# Epoch 154/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0473 - mae: 0.1522
# Epoch 155/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0482 - mae: 0.1566
# Epoch 156/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0474 - mae: 0.1569
# Epoch 157/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0465 - mae: 0.1508
# Epoch 158/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0459 - mae: 0.1467
# Epoch 159/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0448 - mae: 0.1507
# Epoch 160/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0447 - mae: 0.1458
# Epoch 161/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0445 - mae: 0.1448
# Epoch 162/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0443 - mae: 0.1434
# Epoch 163/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0432 - mae: 0.1441
# Epoch 164/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0431 - mae: 0.1431
# Epoch 165/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0425 - mae: 0.1426
# Epoch 166/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0530 - mae: 0.1694
# Epoch 167/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0436 - mae: 0.1407
# Epoch 168/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0428 - mae: 0.1413
# Epoch 169/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0483 - mae: 0.1516
# Epoch 170/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0467 - mae: 0.1497
# Epoch 171/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0436 - mae: 0.1429
# Epoch 172/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0440 - mae: 0.1423
# Epoch 173/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0429 - mae: 0.1422
# Epoch 174/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0436 - mae: 0.1426
# Epoch 175/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0448 - mae: 0.1448
# Epoch 176/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0425 - mae: 0.1420
# Epoch 177/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0479 - mae: 0.1544
# Epoch 178/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0595 - mae: 0.1859
# Epoch 179/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0478 - mae: 0.1604
# Epoch 180/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0471 - mae: 0.1501
# Epoch 181/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0438 - mae: 0.1491
# Epoch 182/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0458 - mae: 0.1541
# Epoch 183/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0407 - mae: 0.1368
# Epoch 184/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0515 - mae: 0.1572
# Epoch 185/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0469 - mae: 0.1555
# Epoch 186/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0414 - mae: 0.1379
# Epoch 187/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0429 - mae: 0.1432
# Epoch 188/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0456 - mae: 0.1513
# Epoch 189/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0415 - mae: 0.1368
# Epoch 190/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0478 - mae: 0.1548
# Epoch 191/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0430 - mae: 0.1397
# Epoch 192/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0460 - mae: 0.1516
# Epoch 193/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0417 - mae: 0.1404
# Epoch 194/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0462 - mae: 0.1505
# Epoch 195/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0518 - mae: 0.1641
# Epoch 196/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0450 - mae: 0.1450
# Epoch 197/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0543 - mae: 0.1705
# Epoch 198/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0424 - mae: 0.1374
# Epoch 199/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0410 - mae: 0.1388
# Epoch 200/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0468 - mae: 0.1609
# Epoch 201/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0559 - mae: 0.1759
# Epoch 202/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0475 - mae: 0.1537
# Epoch 203/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0512 - mae: 0.1566
# Epoch 204/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0498 - mae: 0.1609
# Epoch 205/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0428 - mae: 0.1489
# Epoch 206/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0437 - mae: 0.1441
# Epoch 207/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0467 - mae: 0.1520
# Epoch 208/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0431 - mae: 0.1385
# Epoch 209/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0428 - mae: 0.1480
# Epoch 210/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0403 - mae: 0.1385
# Epoch 211/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0420 - mae: 0.1420
# Epoch 212/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0490 - mae: 0.1630
# Epoch 213/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0542 - mae: 0.1701
# Epoch 214/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0462 - mae: 0.1432
# Epoch 215/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0412 - mae: 0.1395
# Epoch 216/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0492 - mae: 0.1596
# Epoch 217/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0453 - mae: 0.1526
# Epoch 218/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0399 - mae: 0.1334
# Epoch 219/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0603 - mae: 0.1764
# Epoch 220/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0474 - mae: 0.1524
# Epoch 221/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0507 - mae: 0.1616
# Epoch 222/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0488 - mae: 0.1585
# Epoch 223/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0431 - mae: 0.1411
# Epoch 224/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0454 - mae: 0.1488
# Epoch 225/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0429 - mae: 0.1434
# Epoch 226/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0548 - mae: 0.1725
# Epoch 227/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0462 - mae: 0.1478
# Epoch 228/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0522 - mae: 0.1663
# Epoch 229/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0455 - mae: 0.1541
# Epoch 230/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0424 - mae: 0.1452
# Epoch 231/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0599 - mae: 0.1746
# Epoch 232/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0453 - mae: 0.1514
# Epoch 233/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0419 - mae: 0.1469
# Epoch 234/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0439 - mae: 0.1472
# Epoch 235/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0459 - mae: 0.1473
# Epoch 236/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0487 - mae: 0.1593
# Epoch 237/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0536 - mae: 0.1681
# Epoch 238/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0655 - mae: 0.1984
# Epoch 239/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0464 - mae: 0.1571
# Epoch 240/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0425 - mae: 0.1440
# Epoch 241/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0589 - mae: 0.1787
# Epoch 242/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0457 - mae: 0.1509
# Epoch 243/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0540 - mae: 0.1685
# Epoch 244/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0436 - mae: 0.1473
# Epoch 245/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0472 - mae: 0.1587
# Epoch 246/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0455 - mae: 0.1489
# Epoch 247/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0466 - mae: 0.1482
# Epoch 248/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0502 - mae: 0.1643
# Epoch 249/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2179 - mae: 0.3776
# Epoch 250/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0821 - mae: 0.2184
# Epoch 251/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0608 - mae: 0.1914
# Epoch 252/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0733 - mae: 0.2092
# Epoch 253/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0918 - mae: 0.2395
# Epoch 254/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0485 - mae: 0.1612
# Epoch 255/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0613 - mae: 0.1885
# Epoch 256/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0452 - mae: 0.1516
# Epoch 257/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0431 - mae: 0.1462
# Epoch 258/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0413 - mae: 0.1400
# Epoch 259/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0393 - mae: 0.1366
# Epoch 260/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0508 - mae: 0.1637
# Epoch 261/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0608 - mae: 0.1786
# Epoch 262/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0486 - mae: 0.1564
# Epoch 263/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0532 - mae: 0.1709
# Epoch 264/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0511 - mae: 0.1617
# Epoch 265/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0432 - mae: 0.1426
# Epoch 266/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0535 - mae: 0.1630
# Epoch 267/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0412 - mae: 0.1423
# Epoch 268/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1729 - mae: 0.3299
# Epoch 269/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0551 - mae: 0.1684
# Epoch 270/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0653 - mae: 0.1785
# Epoch 271/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0513 - mae: 0.1682
# Epoch 272/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0474 - mae: 0.1592
# Epoch 273/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0445 - mae: 0.1464
# Epoch 274/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0423 - mae: 0.1438
# Epoch 275/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0503 - mae: 0.1642
# Epoch 276/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0421 - mae: 0.1469
# Epoch 277/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0437 - mae: 0.1480
# Epoch 278/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0657 - mae: 0.1940
# Epoch 279/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0563 - mae: 0.1790
# Epoch 280/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0443 - mae: 0.1521
# Epoch 281/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0464 - mae: 0.1566
# Epoch 282/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0674 - mae: 0.1924
# Epoch 283/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0536 - mae: 0.1645
# Epoch 284/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0696 - mae: 0.2028
# Epoch 285/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0496 - mae: 0.1548
# Epoch 286/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0502 - mae: 0.1589
# Epoch 287/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0506 - mae: 0.1635
# Epoch 288/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0468 - mae: 0.1605
# Epoch 289/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0878 - mae: 0.2263
# Epoch 290/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0687 - mae: 0.1978
# Epoch 291/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0993 - mae: 0.2423
# Epoch 292/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0651 - mae: 0.1859
# Epoch 293/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0678 - mae: 0.1924
# Epoch 294/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0957 - mae: 0.2389
# Epoch 295/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0892 - mae: 0.2239
# Epoch 296/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0561 - mae: 0.1707
# Epoch 297/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0550 - mae: 0.1751
# Epoch 298/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0731 - mae: 0.2057
# Epoch 299/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0821 - mae: 0.2208
# Epoch 300/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0522 - mae: 0.1667

# %%
model_mlp.summary()
# Out:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_44 (Dense)                │ (None, 120)            │         1,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 60)             │         7,260 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 1)              │            61 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,645 (104.09 KB)
#  Trainable params: 8,881 (34.69 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 17,764 (69.39 KB)

# %%
# get_weights() retorna uma lista: o primeiro item é a matriz de pesos (W), o segundo é o viés (b)
pesos, vies = model_mlp.get_layer(index=0).get_weights()

print(f"pesos: {pesos.flatten()} e o viés: {vies[0]:.4f}")
# Out:
# pesos: [ 0.22558391 -0.24480687  0.05578373 ... -0.01546687 -0.18434316
#   0.06176034] e o viés: 0.4190

# %%
data_min = scaler.data_min_
scale = scaler.scale_

# w = pesos / scale (scale is the range: 1/(max - min))
w = pesos / scale[:, np.newaxis]
b_raw = vies - np.dot(data_min, w)

w_escalar = w[0][0]
b_raw_escalar = b_raw[0]

print(f"Pesos desnormalizados: {w.flatten()}")
print(f"Viés desnormalizado: {b_raw_escalar:.4f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[194], line 1
# ----> 1 medias = scaler.mean_
#       2 desvios = scaler.scale_
#       4 #w = pesos / desvios
#
# AttributeError: 'MinMaxScaler' object has no attribute 'mean_'

# %%
plt.figure(figsize=(10, 5))

# Plotando a Perda (MSE)
plt.subplot(1, 2, 1)
plt.plot(historico.history['loss'], label='Erro Quadrático Médio (MSE)', color='red')
plt.title('Curva de Aprendizado - Loss')
plt.xlabel('Épocas')
plt.ylabel('MSE')
plt.legend()
plt.grid(True)

# Plotando a Métrica (MAE)
plt.subplot(1, 2, 2)
plt.plot(historico.history['mae'], label='Erro Médio Absoluto (MAE)', color='blue')
plt.title('Evolução da Métrica - MAE')
plt.xlabel('Épocas')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
erro_simples = model_mlp.evaluate(X_test_scaled, y_test, verbose=0)[1]
print(f"Erro Médio Absoluto (Simples): {erro_simples:.2f}\n")
# Out:
# Erro Médio Absoluto (Simples): 1.17

# %% [markdown]
# Valores Reais para testar previsões

# %%
plt.figure(figsize=(10, 6))
y_pred = model_mlp.predict(X_test_scaled)   
plt.plot(y_test, label='Valores Reais', marker='o')
plt.plot(y_pred, label='Previsões MLP', marker='x')
plt.title('Previsões vs Valores Reais - MLP')
plt.xlabel('Amostras de Teste')
plt.ylabel('Voltage')
plt.legend()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

current_input = X_test_scaled[0].copy().reshape(1, -1) 
recurrent_prediction = []
n_steps = 50

# Parâmetros do MinMaxScaler para a coluna 0 (shift_1)
min_voltagem = scaler.data_min_[0]
fator_escala = scaler.scale_[0]

for _ in range(n_steps):
    # Previsão da voltagem real
    next_pred = model_mlp.predict(current_input, verbose=0)[0][0]  
    recurrent_prediction.append(next_pred)  
    
    # 🔴 NOVO CÁLCULO DE ESCALA: Transforma o valor real num valor entre 0 e 1
    next_pred_scaled = (next_pred - min_voltagem) * fator_escala
    
    # Desloca a fila do tempo
    current_input = np.roll(current_input, shift=1, axis=1)  
    
    # Insere a nova previsão escalonada (agora entre 0 e 1)
    current_input[0, 0] = next_pred_scaled


# Extraindo os valores reais e achatando para evitar problemas de shape
y_true_50 = y_test[:n_steps].flatten()

mse = mean_squared_error(y_true_50, recurrent_prediction)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true_50, recurrent_prediction)

print(f"MSE:  {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}\n")

plt.figure(figsize=(10, 6))

plt.plot(y_true_50, label='Valores Reais', marker='o', color='dodgerblue', alpha=0.8)
plt.plot(recurrent_prediction, label='Previsões Recursivas MLP', marker='X', color='crimson', linestyle='--', alpha=0.9)

plt.title(f'Previsões Recursivas vs Valores Reais - MLP (Primeiros {n_steps} Passos)')
plt.xlabel('Passos de Tempo (Futuro)')
plt.ylabel('Voltage')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# MSE:  2.6938
# RMSE: 1.6413
# MAE:  1.5220
