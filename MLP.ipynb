# %% [markdown]
# ## Exploratory Analisys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import io

# %%
data = pd.read_csv('sensors.csv', sep = ',')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6928 entries, 0 to 6927
# Data columns (total 95 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 6927 non-null   object
#  1   Total Voltage (V)    6927 non-null   object
#  2   Average Voltage (V)  6927 non-null   float64
#  3   sensor 1             6927 non-null   float64
#  4   sensor 2             6927 non-null   float64
#  5   sensor 3             6927 non-null   float64
#  6   sensor 4             6927 non-null   float64
#  7   sensor 5             6927 non-null   float64
#  8   sensor 6             6927 non-null   float64
#  9   sensor 7             6927 non-null   float64
#  10  sensor 8             6927 non-null   float64
#  11  sensor 9             6927 non-null   float64
#  12  sensor 10            6927 non-null   float64
#  13  sensor 11            6927 non-null   float64
#  14  sensor 12            6927 non-null   float64
#  15  sensor 13            6927 non-null   float64
#  16  sensor 14            6927 non-null   float64
#  17  sensor 15            6927 non-null   float64
#  18  sensor 16            6927 non-null   float64
#  19  sensor 17            6927 non-null   float64
#  20  sensor 18            6927 non-null   float64
#  21  sensor 19            6927 non-null   float64
#  22  sensor 20            6927 non-null   float64
#  23  sensor 21            6927 non-null   float64
#  24  sensor 22            6927 non-null   float64
#  25  sensor 23            6927 non-null   float64
#  26  sensor 24            6927 non-null   float64
#  27  sensor 25            6927 non-null   float64
#  28  sensor 26            6927 non-null   float64
#  29  sensor 27            6927 non-null   float64
#  30  sensor 28            6927 non-null   float64
#  31  sensor 29            6927 non-null   float64
#  32  sensor 30            6927 non-null   float64
#  33  sensor 31            6927 non-null   float64
#  34  sensor 32            6927 non-null   float64
#  35  sensor 33            6927 non-null   float64
#  36  sensor 34            6927 non-null   float64
#  37  sensor 35            6927 non-null   float64
#  38  sensor 36            6927 non-null   float64
#  39  sensor 37            6927 non-null   float64
#  40  sensor 38            6927 non-null   float64
#  41  sensor 39            6927 non-null   float64
#  42  sensor 40            6927 non-null   float64
#  43  sensor 41            6927 non-null   float64
#  44  sensor 42            6927 non-null   float64
#  45  sensor 43            6927 non-null   float64
#  46  sensor 44            6927 non-null   float64
#  47  sensor 45            6927 non-null   float64
#  48  sensor 46            6927 non-null   float64
#  49  sensor 47            6927 non-null   float64
#  50  sensor 48            6927 non-null   float64
#  51  sensor 49            6927 non-null   float64
#  52  sensor 50            6927 non-null   float64
#  53  sensor 51            6927 non-null   float64
#  54  sensor 52            6927 non-null   float64
#  55  sensor 53            6927 non-null   float64
#  56  sensor 54            6927 non-null   float64
#  57  sensor 55            6927 non-null   float64
#  58  sensor 56            6927 non-null   float64
#  59  sensor 57            6927 non-null   float64
#  60  sensor 58            6927 non-null   float64
#  61  sensor 59            6927 non-null   float64
#  62  sensor 60            6927 non-null   float64
#  63  sensor 61            6927 non-null   float64
#  64  sensor 62            6927 non-null   float64
#  65  sensor 63            6927 non-null   float64
#  66  sensor 64            6927 non-null   float64
#  67  sensor 65            6927 non-null   float64
#  68  sensor 66            6927 non-null   float64
#  69  sensor 67            6927 non-null   float64
#  70  sensor 68            6927 non-null   float64
#  71  sensor 69            6927 non-null   float64
#  72  sensor 70            6927 non-null   float64
#  73  sensor 71            6927 non-null   float64
#  74  sensor 72            6927 non-null   float64
#  75  sensor 73            6927 non-null   float64
#  76  sensor 74            6927 non-null   float64
#  77  sensor 75            6927 non-null   float64
#  78  sensor 76            6927 non-null   float64
#  79  sensor 77            6927 non-null   float64
#  80  sensor 78            6927 non-null   float64
#  81  sensor 79            6927 non-null   float64
#  82  sensor 80            6927 non-null   float64
#  83  sensor 81            6927 non-null   float64
#  84  sensor 82            6927 non-null   float64
#  85  sensor 83            6927 non-null   float64
#  86  sensor 84            6927 non-null   float64
#  87  sensor 85            6927 non-null   float64
#  88  sensor 86            6927 non-null   float64
#  89  sensor 87            6927 non-null   float64
#  90  sensor 88            6927 non-null   float64
#  91  sensor 89            6927 non-null   float64
#  92  sensor 90            6927 non-null   float64
#  93  sensor 91            6927 non-null   float64
#  94  sensor 92            6927 non-null   float64
# dtypes: float64(93), object(2)
# memory usage: 5.0+ MB

# %%
#Dropping columns that are not relevant for the model  
data = data.drop(columns = ['Total Voltage (V)', 'Average Voltage (V)'])

#Converting the 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)


#Checking the first few rows of the updated dataset
data.head(3)
# Out:
#                  Date    sensor 1    sensor 2    sensor 3    sensor 4  \
# 0 2023-04-03 03:00:01  119.121812  115.827723  116.327884  117.658852
# 1 2023-04-03 04:00:01  121.092423  117.628034  118.118468  119.575351
# 2 2023-04-03 05:00:01  121.893561  118.410648  118.866724  120.405980
#
#      sensor 5    sensor 6    sensor 7    sensor 8    sensor 9  ...  \
# 0  117.589612  117.496657  115.859532  114.603809  118.058141  ...
# 1  119.504139  119.387818  117.598619  116.261870  119.998991  ...
# 2  120.332878  120.213393  118.315624  116.951690  120.807357  ...
#
#     sensor 83   sensor 84   sensor 85   sensor 86   sensor 87   sensor 88  \
# 0  115.647812  114.299245  116.471634  115.380364  115.110607  115.910664
# 1  117.329442  115.892439  118.243012  117.071528  116.750911  117.634598
# 2  118.087727  116.615680  119.053043  117.826122  117.492186  118.392878
#
#     sensor 89   sensor 90   sensor 91   sensor 92
# 0  117.049984  114.031306  113.770388  115.565692
# 1  118.956594  115.616289  115.338720  117.255179
# 2  119.695606  116.356843  116.066697  118.036934
#
# [3 rows x 93 columns]

# %% [markdown]
# The fig above show when the site shutdown, and thats it's not a good messure to bring to the model

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data = data, y='sensor 34', x='Date')
plt.title('Voltage Registred by Sensor 34')
plt.ylim(121.5, 130)
plt.xlabel('Date')
plt.ylabel('Voltage')
plt.show()

# %%
data = data[data['sensor 34'] > 121.5 ]
data['sensor 34'].describe()
# Out:
# count    6658.000000
# mean      123.555389
# std         0.805674
# min       121.585035
# 25%       122.852568
# 50%       123.424118
# 75%       124.263571
# max       125.811034
# Name: sensor 34, dtype: float64

# %%
average_s34 = data.groupby(data['Date'].dt.date)['sensor 34'].mean()
average_s34 = average_s34.reset_index()
average_s34.rename(columns={'Date': 'average_daily'}, inplace=True)
average_s34
# Out:
#     average_daily   sensor 34
# 0      2023-04-04  122.444449
# 1      2023-04-05  122.511457
# 2      2023-04-06  122.462247
# 3      2023-04-07  122.558795
# 4      2023-04-08  122.635337
# ..            ...         ...
# 301    2024-04-07  124.854037
# 302    2024-04-08  125.114604
# 303    2024-04-09  124.935289
# 304    2024-04-10  124.929781
# 305    2024-04-11  124.920366
#
# [306 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data = average_s34, x='average_daily', y='sensor 34')
plt.title('Voltage Registred by Sensor 34')
plt.ylim(121.5, 130)
plt.xlabel('Date')
plt.ylabel('Voltage')
plt.show()

# %%
average_s34['diff'] = average_s34['sensor 34'].diff()
average_s34.dropna(inplace=True)
average_s34.head(3)
# Out:
#   average_daily   sensor 34      diff
# 1    2023-04-05  122.511457  0.067008
# 2    2023-04-06  122.462247 -0.049210
# 3    2023-04-07  122.558795  0.096548

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
plot_acf(average_s34['sensor 34'], lags=30, ax=axes[0], alpha=0.05)
axes[0].set_title('Autocorrelação (ACF) - Sensor 34', fontsize=13)
axes[0].set_xlabel('Lags')
axes[0].set_ylabel('Correlação')
axes[0].grid(True, alpha=0.3)

plot_pacf(average_s34['sensor 34'], lags=30, method='yw', ax=axes[1], alpha=0.05)
axes[1].set_title('Autocorrelação Parcial (PACF) - Sensor 34', fontsize=13)
axes[1].set_xlabel('Lags')
axes[1].set_ylabel('Correlação Parcial')
axes[1].grid(True, alpha=0.3)

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
plot_acf(average_s34['diff'], lags=30, ax=axes[0], alpha=0.05)
axes[0].set_title('Autocorrelação (ACF) - Diff Sensor 34', fontsize=13)
axes[0].set_xlabel('Lags')
axes[0].set_ylabel('Correlação')
axes[0].grid(True, alpha=0.3)

plot_pacf(average_s34['diff'], lags=30, method='yw', ax=axes[1], alpha=0.05)
axes[1].set_title('Autocorrelação Parcial (PACF) - Diff Sensor 34', fontsize=13)
axes[1].set_xlabel('Lags')
axes[1].set_ylabel('Correlação Parcial')
axes[1].grid(True, alpha=0.3)

# %% [markdown]
# ## Features

# %% [markdown]
# Separating into test and training sets

# %%
for i in range(1, 4, 1):
        average_s34[f'shift_{i}'] = average_s34['sensor 34'].shift(i)
average_s34.dropna(inplace=True)

y = average_s34['sensor 34'].values.reshape(-1, 1).astype('float32')
X = average_s34[[f'shift_{i}' for i in range(1, 4)]].values.astype('float32')  # Usando os valores dos 8 dias anteriores como recursos


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False) #shuffle=False to maintain the time series order

# %%
preview = pd.DataFrame(X_train, columns=[f'shift_{i}' for i in range(1, 4)])
preview.head(3)
# Out:
#       shift_1     shift_2     shift_3
# 0  122.558792  122.462250  122.511459
# 1  122.635338  122.558792  122.462250
# 2  122.505692  122.635338  122.558792

# %%
X.shape, y.shape
# Out:
# ((302, 3), (302, 1))

# %% [markdown]
# Normalizando dados

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test) #Evitar datalake

# %% [markdown]
# Hiperparâmetros

# %%
TAXA_APRENDIZADO = 0.001  # Tamanho do "passo" na otimização (ex: 0.1, 0.01, 0.001)
EPOCAS = 300             # Quantas vezes a rede verá todo o dataset
TAMANHO_LOTE = 10         # Batch size

# %% [markdown]
# Aplicando o treinamento

# %%
#Construção da arquitetura
#Camada de Entrada
model_mlp = Sequential([Dense(32, # 64 Neurônio nesta camada (Z = W*X + b)
                                  input_shape=(3,), # Quantidade de variáveis que vão entrar ( Z = w1*x1 + w2*x2 + b)
                                  activation='relu') ]) # Especificando qual vai ser o tipo de ativação. Ex: reLu, linear, tanh, sigmoid...


#Camada Oculta 1
model_mlp.add(Dense(16, activation='relu'))

#Camada de Saída
model_mlp.add(Dense(1, activation='linear')) # 1 Neurônio nesta camada (Z = W*X + b) --- IGNORE ---, ativação linear para regressão


#Configuração
model_mlp.compile(
    optimizer=Adam(learning_rate=TAXA_APRENDIZADO), #Aplicação do modelo de Gradiente descendente, usando o leanning rate proposto
    loss='mse', # Qual a função da loss. Nesse caso o mse é (Z - F(x1,x2))²
    metrics=['mae'] # Erro Médio Absoluto para termos uma métrica mais legível
)

#Treinamento
historico = model_mlp.fit(
    X_train_scaled, y_train, #Indica quais são as bases
    epochs=EPOCAS, batch_size=TAMANHO_LOTE, #O batch_size é a batelada de cada iteração (epoch) que será calculada
    verbose=1 # Mude para 1 se quiser ver o log de cada época
)
# Out:
# Epoch 1/300
# c:\Projeto de Manutenção\Maintenance-prediction\.venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15077.0771 - mae: 122.7856
# Epoch 2/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14888.7676 - mae: 122.0136
# Epoch 3/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14625.2197 - mae: 120.9229
# Epoch 4/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14218.8125 - mae: 119.2156
# Epoch 5/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13635.3984 - mae: 116.7160
# Epoch 6/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12774.1758 - mae: 112.8974
# Epoch 7/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11623.8984 - mae: 107.5577
# Epoch 8/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10153.3154 - mae: 100.2724
# Epoch 9/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8467.0537 - mae: 91.0276
# Epoch 10/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6692.9380 - mae: 79.7869
# Epoch 11/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5052.9951 - mae: 67.4982
# Epoch 12/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3716.7014 - mae: 55.5135
# Epoch 13/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2763.2173 - mae: 44.6254
# Epoch 14/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2199.7488 - mae: 37.9409
# Epoch 15/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1898.0002 - mae: 35.7778
# Epoch 16/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1744.2185 - mae: 34.6390
# Epoch 17/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1637.3115 - mae: 34.0029
# Epoch 18/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1556.1392 - mae: 33.4685
# Epoch 19/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1476.2346 - mae: 32.7864
# Epoch 20/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1401.3815 - mae: 31.9654
# Epoch 21/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1326.9652 - mae: 31.1340
# Epoch 22/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1254.5352 - mae: 30.3524
# Epoch 23/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1181.4541 - mae: 29.5153
# Epoch 24/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1102.1293 - mae: 28.5252
# Epoch 25/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1021.9868 - mae: 27.4916
# Epoch 26/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 943.4567 - mae: 26.4991
# Epoch 27/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 853.2469 - mae: 25.1835
# Epoch 28/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 774.6387 - mae: 23.9834
# Epoch 29/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 695.8688 - mae: 22.6937
# Epoch 30/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 620.1618 - mae: 21.3398
# Epoch 31/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 550.4891 - mae: 19.9949
# Epoch 32/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 483.8386 - mae: 18.6713
# Epoch 33/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 423.3173 - mae: 17.3556
# Epoch 34/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 368.5270 - mae: 16.1068
# Epoch 35/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 318.4504 - mae: 14.8552
# Epoch 36/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 274.5167 - mae: 13.7270
# Epoch 37/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 238.9627 - mae: 12.7167
# Epoch 38/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 205.3749 - mae: 11.7482
# Epoch 39/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 178.5895 - mae: 10.9185
# Epoch 40/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 155.3751 - mae: 10.1585
# Epoch 41/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 137.0881 - mae: 9.4603
# Epoch 42/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 120.3018 - mae: 8.8916
# Epoch 43/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 107.2877 - mae: 8.3384
# Epoch 44/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 94.3452 - mae: 7.7422
# Epoch 45/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 83.9360 - mae: 7.2471
# Epoch 46/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 73.4966 - mae: 6.7221
# Epoch 47/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 65.0118 - mae: 6.3475
# Epoch 48/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 56.7724 - mae: 5.8567
# Epoch 49/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50.4177 - mae: 5.4726
# Epoch 50/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.6552 - mae: 5.0724
# Epoch 51/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.4987 - mae: 4.7171
# Epoch 52/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.2060 - mae: 4.4408
# Epoch 53/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.3408 - mae: 4.1386
# Epoch 54/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.4804 - mae: 3.8890
# Epoch 55/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.0329 - mae: 3.6067
# Epoch 56/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.3481 - mae: 3.3486
# Epoch 57/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.9920 - mae: 3.1543
# Epoch 58/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.9620 - mae: 2.9685
# Epoch 59/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.2385 - mae: 2.7942
# Epoch 60/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.7190 - mae: 2.6055
# Epoch 61/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.3747 - mae: 2.4589
# Epoch 62/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.1421 - mae: 2.2855
# Epoch 63/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.0654 - mae: 2.1654
# Epoch 64/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.4869 - mae: 2.1198
# Epoch 65/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2695 - mae: 1.9327
# Epoch 66/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5040 - mae: 1.8315
# Epoch 67/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8714 - mae: 1.7389
# Epoch 68/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3178 - mae: 1.6574
# Epoch 69/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7823 - mae: 1.5771
# Epoch 70/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3238 - mae: 1.4929
# Epoch 71/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8732 - mae: 1.4517
# Epoch 72/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5816 - mae: 1.4004
# Epoch 73/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1654 - mae: 1.3727
# Epoch 74/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0482 - mae: 1.3356
# Epoch 75/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5530 - mae: 1.3052
# Epoch 76/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3022 - mae: 1.2695
# Epoch 77/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1028 - mae: 1.2042
# Epoch 78/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9227 - mae: 1.2108
# Epoch 79/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7525 - mae: 1.1863
# Epoch 80/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6140 - mae: 1.2370
# Epoch 81/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4084 - mae: 1.1626
# Epoch 82/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3948 - mae: 1.1174
# Epoch 83/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2307 - mae: 1.1944
# Epoch 84/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0845 - mae: 1.0916
# Epoch 85/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0289 - mae: 1.1239
# Epoch 86/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8601 - mae: 1.0963
# Epoch 87/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7744 - mae: 1.0875
# Epoch 88/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7123 - mae: 1.1034
# Epoch 89/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6723 - mae: 1.1215
# Epoch 90/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6157 - mae: 1.0350
# Epoch 91/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5342 - mae: 1.0922
# Epoch 92/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5192 - mae: 1.0439
# Epoch 93/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4000 - mae: 1.0711
# Epoch 94/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3313 - mae: 1.0218
# Epoch 95/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3282 - mae: 1.0679
# Epoch 96/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2624 - mae: 1.0127
# Epoch 97/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2135 - mae: 1.0684
# Epoch 98/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1759 - mae: 1.0328
# Epoch 99/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1284 - mae: 1.0347
# Epoch 100/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1025 - mae: 0.9808
# Epoch 101/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0131 - mae: 0.9916
# Epoch 102/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0753 - mae: 1.0320
# Epoch 103/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9856 - mae: 0.9859
# Epoch 104/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9245 - mae: 0.9751
# Epoch 105/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8793 - mae: 0.9472
# Epoch 106/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8506 - mae: 0.9836
# Epoch 107/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8137 - mae: 0.9475
# Epoch 108/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7738 - mae: 0.9595
# Epoch 109/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7742 - mae: 0.9263
# Epoch 110/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7125 - mae: 0.9387
# Epoch 111/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6789 - mae: 0.9122
# Epoch 112/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6371 - mae: 0.9334
# Epoch 113/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6752 - mae: 0.9168
# Epoch 114/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5934 - mae: 0.9054
# Epoch 115/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5462 - mae: 0.9223
# Epoch 116/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5317 - mae: 0.9103
# Epoch 117/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4774 - mae: 0.8932
# Epoch 118/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4496 - mae: 0.8572
# Epoch 119/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4278 - mae: 0.8889
# Epoch 120/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3962 - mae: 0.8346
# Epoch 121/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3557 - mae: 0.8473
# Epoch 122/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3335 - mae: 0.8696
# Epoch 123/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3405 - mae: 0.8158
# Epoch 124/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3042 - mae: 0.8649
# Epoch 125/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3546 - mae: 0.8377
# Epoch 126/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2305 - mae: 0.8228
# Epoch 127/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2072 - mae: 0.7835
# Epoch 128/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2359 - mae: 0.8826
# Epoch 129/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1656 - mae: 0.7733
# Epoch 130/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1650 - mae: 0.8628
# Epoch 131/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1331 - mae: 0.7739
# Epoch 132/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0952 - mae: 0.7832
# Epoch 133/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0958 - mae: 0.7802
# Epoch 134/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0685 - mae: 0.7488
# Epoch 135/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0858 - mae: 0.7956
# Epoch 136/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0765 - mae: 0.7828
# Epoch 137/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0062 - mae: 0.7327
# Epoch 138/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9896 - mae: 0.7277
# Epoch 139/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0095 - mae: 0.7544
# Epoch 140/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9738 - mae: 0.7745
# Epoch 141/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9539 - mae: 0.7159
# Epoch 142/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9359 - mae: 0.7110
# Epoch 143/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9335 - mae: 0.7321
# Epoch 144/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8945 - mae: 0.6995
# Epoch 145/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8726 - mae: 0.6919
# Epoch 146/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8607 - mae: 0.7088
# Epoch 147/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8464 - mae: 0.6911
# Epoch 148/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8447 - mae: 0.6814
# Epoch 149/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8155 - mae: 0.6781
# Epoch 150/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8043 - mae: 0.6909
# Epoch 151/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7775 - mae: 0.6609
# Epoch 152/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7666 - mae: 0.6575
# Epoch 153/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0633 - mae: 0.8272
# Epoch 154/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7474 - mae: 0.6537
# Epoch 155/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7326 - mae: 0.6377
# Epoch 156/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7168 - mae: 0.6468
# Epoch 157/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6932 - mae: 0.6353
# Epoch 158/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6811 - mae: 0.6283
# Epoch 159/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6638 - mae: 0.6289
# Epoch 160/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6820 - mae: 0.6277
# Epoch 161/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6673 - mae: 0.6360
# Epoch 162/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6240 - mae: 0.5986
# Epoch 163/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6483 - mae: 0.6423
# Epoch 164/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6122 - mae: 0.5876
# Epoch 165/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5994 - mae: 0.5950
# Epoch 166/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5928 - mae: 0.5904
# Epoch 167/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5904 - mae: 0.5872
# Epoch 168/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5777 - mae: 0.5884
# Epoch 169/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5609 - mae: 0.5616
# Epoch 170/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5598 - mae: 0.5786
# Epoch 171/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5239 - mae: 0.5599
# Epoch 172/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5361 - mae: 0.5603
# Epoch 173/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7725 - mae: 0.7067
# Epoch 174/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5428 - mae: 0.5595
# Epoch 175/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5102 - mae: 0.5444
# Epoch 176/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4991 - mae: 0.5511
# Epoch 177/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4953 - mae: 0.5450
# Epoch 178/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4572 - mae: 0.5153
# Epoch 179/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4571 - mae: 0.5212
# Epoch 180/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4531 - mae: 0.5145
# Epoch 181/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4303 - mae: 0.5112
# Epoch 182/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4347 - mae: 0.5023
# Epoch 183/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4198 - mae: 0.4894
# Epoch 184/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4079 - mae: 0.4876
# Epoch 185/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4298 - mae: 0.4988
# Epoch 186/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4107 - mae: 0.4898
# Epoch 187/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3997 - mae: 0.4891
# Epoch 188/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5455 - mae: 0.5710
# Epoch 189/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3893 - mae: 0.4695
# Epoch 190/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3659 - mae: 0.4617
# Epoch 191/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3618 - mae: 0.4606
# Epoch 192/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3656 - mae: 0.4578
# Epoch 193/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3710 - mae: 0.4608
# Epoch 194/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3711 - mae: 0.4672
# Epoch 195/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3776 - mae: 0.4551
# Epoch 196/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3425 - mae: 0.4375
# Epoch 197/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3493 - mae: 0.4419
# Epoch 198/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3305 - mae: 0.4324
# Epoch 199/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3259 - mae: 0.4240
# Epoch 200/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3192 - mae: 0.4324
# Epoch 201/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3096 - mae: 0.4196
# Epoch 202/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3098 - mae: 0.4137
# Epoch 203/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2931 - mae: 0.4128
# Epoch 204/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3103 - mae: 0.4203
# Epoch 205/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3075 - mae: 0.4164
# Epoch 206/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2881 - mae: 0.4070
# Epoch 207/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2832 - mae: 0.4033
# Epoch 208/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2784 - mae: 0.3956
# Epoch 209/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2810 - mae: 0.3935
# Epoch 210/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2770 - mae: 0.4098
# Epoch 211/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2788 - mae: 0.3947
# Epoch 212/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2794 - mae: 0.3964
# Epoch 213/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2656 - mae: 0.3903
# Epoch 214/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2495 - mae: 0.3657
# Epoch 215/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2826 - mae: 0.3937
# Epoch 216/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2488 - mae: 0.3702
# Epoch 217/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2378 - mae: 0.3728
# Epoch 218/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2180 - mae: 0.3588
# Epoch 219/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2165 - mae: 0.3532
# Epoch 220/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2817 - mae: 0.3919
# Epoch 221/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2231 - mae: 0.3541
# Epoch 222/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2121 - mae: 0.3451
# Epoch 223/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2262 - mae: 0.3552
# Epoch 224/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2107 - mae: 0.3443
# Epoch 225/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1997 - mae: 0.3303
# Epoch 226/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1987 - mae: 0.3355
# Epoch 227/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1959 - mae: 0.3233
# Epoch 228/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1876 - mae: 0.3180
# Epoch 229/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1887 - mae: 0.3202
# Epoch 230/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2057 - mae: 0.3499
# Epoch 231/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1860 - mae: 0.3152
# Epoch 232/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1863 - mae: 0.3230
# Epoch 233/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1729 - mae: 0.3132
# Epoch 234/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1780 - mae: 0.3109
# Epoch 235/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1730 - mae: 0.3108
# Epoch 236/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1900 - mae: 0.3249
# Epoch 237/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1581 - mae: 0.2929
# Epoch 238/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1562 - mae: 0.2944
# Epoch 239/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1542 - mae: 0.2941
# Epoch 240/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1515 - mae: 0.2837
# Epoch 241/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1495 - mae: 0.2843
# Epoch 242/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1526 - mae: 0.2865
# Epoch 243/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1555 - mae: 0.2849
# Epoch 244/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1433 - mae: 0.2779
# Epoch 245/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1300 - mae: 0.2588
# Epoch 246/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1283 - mae: 0.2560
# Epoch 247/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1413 - mae: 0.2636
# Epoch 248/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1239 - mae: 0.2646
# Epoch 249/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1319 - mae: 0.2660
# Epoch 250/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1238 - mae: 0.2526
# Epoch 251/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1206 - mae: 0.2469
# Epoch 252/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1286 - mae: 0.2528
# Epoch 253/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1128 - mae: 0.2499
# Epoch 254/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1129 - mae: 0.2407
# Epoch 255/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1188 - mae: 0.2530
# Epoch 256/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1015 - mae: 0.2388
# Epoch 257/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1058 - mae: 0.2350
# Epoch 258/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1344 - mae: 0.2678
# Epoch 259/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0954 - mae: 0.2233
# Epoch 260/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0981 - mae: 0.2238
# Epoch 261/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0956 - mae: 0.2187
# Epoch 262/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1161 - mae: 0.2509
# Epoch 263/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1133 - mae: 0.2518
# Epoch 264/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0955 - mae: 0.2191
# Epoch 265/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0925 - mae: 0.2131
# Epoch 266/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0863 - mae: 0.2073
# Epoch 267/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0843 - mae: 0.2041
# Epoch 268/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1167 - mae: 0.2458
# Epoch 269/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1016 - mae: 0.2220
# Epoch 270/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0814 - mae: 0.2000
# Epoch 271/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0820 - mae: 0.2052
# Epoch 272/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0843 - mae: 0.2071
# Epoch 273/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0793 - mae: 0.2022
# Epoch 274/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0864 - mae: 0.2147
# Epoch 275/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0782 - mae: 0.1981
# Epoch 276/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0716 - mae: 0.1882
# Epoch 277/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0766 - mae: 0.1939
# Epoch 278/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0821 - mae: 0.2087
# Epoch 279/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0786 - mae: 0.2033
# Epoch 280/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0719 - mae: 0.1878
# Epoch 281/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0742 - mae: 0.1933
# Epoch 282/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0734 - mae: 0.1860
# Epoch 283/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0708 - mae: 0.1885
# Epoch 284/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0691 - mae: 0.1894
# Epoch 285/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0737 - mae: 0.1983
# Epoch 286/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0966 - mae: 0.2314
# Epoch 287/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0854 - mae: 0.2030
# Epoch 288/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0696 - mae: 0.1871
# Epoch 289/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0702 - mae: 0.1873
# Epoch 290/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0758 - mae: 0.1991
# Epoch 291/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0665 - mae: 0.1817
# Epoch 292/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0667 - mae: 0.1802
# Epoch 293/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0677 - mae: 0.1833
# Epoch 294/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0651 - mae: 0.1774
# Epoch 295/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0618 - mae: 0.1702
# Epoch 296/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1222 - mae: 0.2721
# Epoch 297/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0788 - mae: 0.2084
# Epoch 298/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0666 - mae: 0.1948
# Epoch 299/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0716 - mae: 0.1967
# Epoch 300/300
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0715 - mae: 0.1950

# %%
model_mlp.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 32)             │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,021 (7.90 KB)
#  Trainable params: 673 (2.63 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,348 (5.27 KB)

# %%
# get_weights() retorna uma lista: o primeiro item é a matriz de pesos (W), o segundo é o viés (b)
pesos, vies = model_mlp.get_layer(index=0).get_weights()

print(f"pesos: {pesos.flatten()} e o viés: {vies[0]:.4f}")
# Out:
# pesos: [ 0.37313166 -0.23555337 -0.13266918  0.02022837  0.1444145   0.26160398
#   0.42025498 -0.02015237 -0.2859385  -0.15434109  0.03930433  0.20029935
#  -0.1464644  -0.27384478 -0.23768033 -0.35833663 -0.41347072 -0.01622163
#  -0.29328957 -0.13229322 -0.2565147   0.37320122  0.28247955  0.39552307
#   0.33136943 -0.07977826 -0.05505193 -0.35253823  0.33992606 -0.3804064
#   0.22865726  0.2163835   0.30033785  0.22925787 -0.27944347 -0.3107693
#   0.0622053   0.17174329  0.50665367 -0.3001155  -0.01420109 -0.00183523
#  -0.1105159   0.18488455 -0.23881266  0.33476672  0.27889305 -0.49955708
#  -0.5082063  -0.16375564  0.16013905 -0.2276951   0.2627404   0.2577824
#   0.10363161 -0.24359299 -0.05154527 -0.26821235 -0.17879295  0.4499051
#   0.21491192 -0.17897762 -0.05169109 -0.33298698  0.21785365  0.3763076
#   0.17820893 -0.03449588  0.3214629   0.09810133  0.69368255  0.11305775
#  -0.01185616 -0.14997385  0.08280981  0.09421308  0.11794462  0.26285428
#   0.27124503 -0.40786687 -0.5863044  -0.43085137 -0.13624355  0.15129957
#  -0.3070577  -0.14367945 -0.31890875 -0.2457078   0.12769201  0.1063667
#  -0.03772557 -0.3261243  -0.11094064 -0.5390607   0.3265814   0.2914279 ] e o viés: 0.9155

# %%
medias = scaler.mean_
desvios = scaler.scale_

#w = pesos / desvios
w = pesos / desvios[:, np.newaxis]
b_raw = vies - np.dot(medias, w)

w_escalar = w[0][0]
b_raw_escalar = b_raw[0]

print(f"Pesos desnormalizados: {w.flatten()}")
print(f"Viés desnormalizado: {b_raw_escalar:.4f}")
# Out:
# Pesos desnormalizados: [ 0.6241755  -0.39403421 -0.22192931  0.03383806  0.2415769   0.43761174
#   0.70300348 -0.03371093 -0.47831858 -0.25818212  0.06574837  0.33506121
#  -0.24500599 -0.45808817 -0.3975922  -0.59942633 -0.69165476 -0.02713558
#  -0.49061547 -0.22130041 -0.42909837  0.62429185  0.47253244  0.6616319
#   0.55431554 -0.13345326 -0.09209099 -0.58972675  0.5686291  -0.63634471
#   0.38249839  0.36196682  0.50412663  0.38481662 -0.46905475 -0.52163613
#   0.10441357  0.28827657  0.85043428 -0.5037534  -0.02383698 -0.00308049
#  -0.18550445  0.31033459 -0.40085463  0.56191657  0.46813085 -0.83852243
#  -0.85304044 -0.27486905  0.26879849 -0.38219345  0.44101812  0.43269595
#   0.17394895 -0.40887858 -0.08652037 -0.45020295 -0.30010966  0.75518001
#   0.36073649 -0.30041963 -0.08676514 -0.55892923  0.36640537  0.63290713
#   0.29972741 -0.05801819  0.54066449  0.16499542  1.16669614  0.19015045
#  -0.01994073 -0.25223918  0.13927679  0.15845583  0.19836961  0.44209137
#   0.45620368 -0.68598626 -0.9860982  -0.72464362 -0.22914635  0.25446888
#  -0.51643658 -0.24165271 -0.5363687  -0.41325292  0.21476363  0.17889685
#  -0.06345017 -0.54850446 -0.18658969 -0.90663958  0.54927322  0.49014901]
# Viés desnormalizado: -183.3487

# %%
plt.figure(figsize=(10, 5))

# Plotando a Perda (MSE)
plt.subplot(1, 2, 1)
plt.plot(historico.history['loss'], label='Erro Quadrático Médio (MSE)', color='red')
plt.title('Curva de Aprendizado - Loss')
plt.xlabel('Épocas')
plt.ylabel('MSE')
plt.legend()
plt.grid(True)

# Plotando a Métrica (MAE)
plt.subplot(1, 2, 2)
plt.plot(historico.history['mae'], label='Erro Médio Absoluto (MAE)', color='blue')
plt.title('Evolução da Métrica - MAE')
plt.xlabel('Épocas')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
erro_simples = model_mlp.evaluate(X_test_scaled, y_test, verbose=0)[1]
print(f"Erro Médio Absoluto (Simples): {erro_simples:.2f}\n")
# Out:
# Erro Médio Absoluto (Simples): 0.99

# %%
plt.figure(figsize=(10, 6))
y_pred = model_mlp.predict(X_test_scaled)   
plt.plot(y_test, label='Valores Reais', marker='o')
plt.plot(y_pred, label='Previsões MLP', marker='x')
plt.title('Previsões vs Valores Reais - MLP')
plt.xlabel('Amostras de Teste')
plt.ylabel('Voltage')
plt.legend()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
