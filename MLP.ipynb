# %% [markdown]
# ## Exploratory Analisys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import io

# %%
data = pd.read_csv('sensors.csv', sep = ',')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6928 entries, 0 to 6927
# Data columns (total 95 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 6927 non-null   object
#  1   Total Voltage (V)    6927 non-null   object
#  2   Average Voltage (V)  6927 non-null   float64
#  3   sensor 1             6927 non-null   float64
#  4   sensor 2             6927 non-null   float64
#  5   sensor 3             6927 non-null   float64
#  6   sensor 4             6927 non-null   float64
#  7   sensor 5             6927 non-null   float64
#  8   sensor 6             6927 non-null   float64
#  9   sensor 7             6927 non-null   float64
#  10  sensor 8             6927 non-null   float64
#  11  sensor 9             6927 non-null   float64
#  12  sensor 10            6927 non-null   float64
#  13  sensor 11            6927 non-null   float64
#  14  sensor 12            6927 non-null   float64
#  15  sensor 13            6927 non-null   float64
#  16  sensor 14            6927 non-null   float64
#  17  sensor 15            6927 non-null   float64
#  18  sensor 16            6927 non-null   float64
#  19  sensor 17            6927 non-null   float64
#  20  sensor 18            6927 non-null   float64
#  21  sensor 19            6927 non-null   float64
#  22  sensor 20            6927 non-null   float64
#  23  sensor 21            6927 non-null   float64
#  24  sensor 22            6927 non-null   float64
#  25  sensor 23            6927 non-null   float64
#  26  sensor 24            6927 non-null   float64
#  27  sensor 25            6927 non-null   float64
#  28  sensor 26            6927 non-null   float64
#  29  sensor 27            6927 non-null   float64
#  30  sensor 28            6927 non-null   float64
#  31  sensor 29            6927 non-null   float64
#  32  sensor 30            6927 non-null   float64
#  33  sensor 31            6927 non-null   float64
#  34  sensor 32            6927 non-null   float64
#  35  sensor 33            6927 non-null   float64
#  36  sensor 34            6927 non-null   float64
#  37  sensor 35            6927 non-null   float64
#  38  sensor 36            6927 non-null   float64
#  39  sensor 37            6927 non-null   float64
#  40  sensor 38            6927 non-null   float64
#  41  sensor 39            6927 non-null   float64
#  42  sensor 40            6927 non-null   float64
#  43  sensor 41            6927 non-null   float64
#  44  sensor 42            6927 non-null   float64
#  45  sensor 43            6927 non-null   float64
#  46  sensor 44            6927 non-null   float64
#  47  sensor 45            6927 non-null   float64
#  48  sensor 46            6927 non-null   float64
#  49  sensor 47            6927 non-null   float64
#  50  sensor 48            6927 non-null   float64
#  51  sensor 49            6927 non-null   float64
#  52  sensor 50            6927 non-null   float64
#  53  sensor 51            6927 non-null   float64
#  54  sensor 52            6927 non-null   float64
#  55  sensor 53            6927 non-null   float64
#  56  sensor 54            6927 non-null   float64
#  57  sensor 55            6927 non-null   float64
#  58  sensor 56            6927 non-null   float64
#  59  sensor 57            6927 non-null   float64
#  60  sensor 58            6927 non-null   float64
#  61  sensor 59            6927 non-null   float64
#  62  sensor 60            6927 non-null   float64
#  63  sensor 61            6927 non-null   float64
#  64  sensor 62            6927 non-null   float64
#  65  sensor 63            6927 non-null   float64
#  66  sensor 64            6927 non-null   float64
#  67  sensor 65            6927 non-null   float64
#  68  sensor 66            6927 non-null   float64
#  69  sensor 67            6927 non-null   float64
#  70  sensor 68            6927 non-null   float64
#  71  sensor 69            6927 non-null   float64
#  72  sensor 70            6927 non-null   float64
#  73  sensor 71            6927 non-null   float64
#  74  sensor 72            6927 non-null   float64
#  75  sensor 73            6927 non-null   float64
#  76  sensor 74            6927 non-null   float64
#  77  sensor 75            6927 non-null   float64
#  78  sensor 76            6927 non-null   float64
#  79  sensor 77            6927 non-null   float64
#  80  sensor 78            6927 non-null   float64
#  81  sensor 79            6927 non-null   float64
#  82  sensor 80            6927 non-null   float64
#  83  sensor 81            6927 non-null   float64
#  84  sensor 82            6927 non-null   float64
#  85  sensor 83            6927 non-null   float64
#  86  sensor 84            6927 non-null   float64
#  87  sensor 85            6927 non-null   float64
#  88  sensor 86            6927 non-null   float64
#  89  sensor 87            6927 non-null   float64
#  90  sensor 88            6927 non-null   float64
#  91  sensor 89            6927 non-null   float64
#  92  sensor 90            6927 non-null   float64
#  93  sensor 91            6927 non-null   float64
#  94  sensor 92            6927 non-null   float64
# dtypes: float64(93), object(2)
# memory usage: 5.0+ MB

# %%
#Dropping columns that are not relevant for the model  
data = data.drop(columns = ['Total Voltage (V)', 'Average Voltage (V)'])

#Converting the 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)


#Checking the first few rows of the updated dataset
data.head(3)
# Out:
#                  Date    sensor 1    sensor 2    sensor 3    sensor 4  \
# 0 2023-04-03 03:00:01  119.121812  115.827723  116.327884  117.658852
# 1 2023-04-03 04:00:01  121.092423  117.628034  118.118468  119.575351
# 2 2023-04-03 05:00:01  121.893561  118.410648  118.866724  120.405980
#
#      sensor 5    sensor 6    sensor 7    sensor 8    sensor 9  ...  \
# 0  117.589612  117.496657  115.859532  114.603809  118.058141  ...
# 1  119.504139  119.387818  117.598619  116.261870  119.998991  ...
# 2  120.332878  120.213393  118.315624  116.951690  120.807357  ...
#
#     sensor 83   sensor 84   sensor 85   sensor 86   sensor 87   sensor 88  \
# 0  115.647812  114.299245  116.471634  115.380364  115.110607  115.910664
# 1  117.329442  115.892439  118.243012  117.071528  116.750911  117.634598
# 2  118.087727  116.615680  119.053043  117.826122  117.492186  118.392878
#
#     sensor 89   sensor 90   sensor 91   sensor 92
# 0  117.049984  114.031306  113.770388  115.565692
# 1  118.956594  115.616289  115.338720  117.255179
# 2  119.695606  116.356843  116.066697  118.036934
#
# [3 rows x 93 columns]

# %% [markdown]
# The fig above show when the site shutdown, and thats it's not a good messure to bring to the model

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data = data, y='sensor 34', x='Date')
plt.title('Voltage Registred by Sensor 34')
plt.ylim(121.5, 130)
plt.xlabel('Date')
plt.ylabel('Voltage')
plt.show()

# %%
data = data[data['sensor 34'] > 121.5 ]
data['sensor 34'].describe()
# Out:
# count    6658.000000
# mean      123.555389
# std         0.805674
# min       121.585035
# 25%       122.852568
# 50%       123.424118
# 75%       124.263571
# max       125.811034
# Name: sensor 34, dtype: float64

# %%
average_s34 = data.groupby(data['Date'].dt.date)['sensor 34'].mean()
average_s34 = average_s34.reset_index()
average_s34.rename(columns={'Date': 'average_daily'}, inplace=True)
average_s34
# Out:
#     average_daily   sensor 34
# 0      2023-04-04  122.444449
# 1      2023-04-05  122.511457
# 2      2023-04-06  122.462247
# 3      2023-04-07  122.558795
# 4      2023-04-08  122.635337
# ..            ...         ...
# 301    2024-04-07  124.854037
# 302    2024-04-08  125.114604
# 303    2024-04-09  124.935289
# 304    2024-04-10  124.929781
# 305    2024-04-11  124.920366
#
# [306 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data = average_s34, x='average_daily', y='sensor 34')
plt.title('Voltage Registred by Sensor 34')
plt.ylim(121.5, 130)
plt.xlabel('Date')
plt.ylabel('Voltage')
plt.show()

# %%
average_s34['diff'] = average_s34['sensor 34'].diff()
average_s34.dropna(inplace=True)
average_s34.head(3)
# Out:
#   average_daily   sensor 34      diff
# 1    2023-04-05  122.511457  0.067008
# 2    2023-04-06  122.462247 -0.049210
# 3    2023-04-07  122.558795  0.096548

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
plot_acf(average_s34['sensor 34'], lags=30, ax=axes[0], alpha=0.05)
axes[0].set_title('Autocorrelação (ACF) - Sensor 34', fontsize=13)
axes[0].set_xlabel('Lags')
axes[0].set_ylabel('Correlação')
axes[0].grid(True, alpha=0.3)

plot_pacf(average_s34['sensor 34'], lags=30, method='yw', ax=axes[1], alpha=0.05)
axes[1].set_title('Autocorrelação Parcial (PACF) - Sensor 34', fontsize=13)
axes[1].set_xlabel('Lags')
axes[1].set_ylabel('Correlação Parcial')
axes[1].grid(True, alpha=0.3)

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
plot_acf(average_s34['diff'], lags=30, ax=axes[0], alpha=0.05)
axes[0].set_title('Autocorrelação (ACF) - Diff Sensor 34', fontsize=13)
axes[0].set_xlabel('Lags')
axes[0].set_ylabel('Correlação')
axes[0].grid(True, alpha=0.3)

plot_pacf(average_s34['diff'], lags=30, method='yw', ax=axes[1], alpha=0.05)
axes[1].set_title('Autocorrelação Parcial (PACF) - Diff Sensor 34', fontsize=13)
axes[1].set_xlabel('Lags')
axes[1].set_ylabel('Correlação Parcial')
axes[1].grid(True, alpha=0.3)

# %% [markdown]
# ## Features

# %% [markdown]
# Separating into test and training sets

# %%
for i in range(1, 3, 1):
        average_s34[f'shift_{i}'] = average_s34['sensor 34'].shift(i)
average_s34.dropna(inplace=True)

y = average_s34['sensor 34'].values.reshape(-1, 1).astype('float32')
X = average_s34[[f'shift_{i}' for i in range(1, 3)]].values.astype('float32')  # Usando os valores dos 8 dias anteriores como recursos


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False) #shuffle=False to maintain the time series order

# %%
preview = pd.DataFrame(X_train, columns=[f'shift_{i}' for i in range(1, 3)])
preview.head(3)
# Out:
#       shift_1     shift_2
# 0  122.462250  122.511459
# 1  122.558792  122.462250
# 2  122.635338  122.558792

# %%
X.shape, y.shape
# Out:
# ((303, 2), (303, 1))

# %% [markdown]
# Normalizando dados

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test) #Evitar datalake

# %% [markdown]
# Hiperparâmetros

# %%
TAXA_APRENDIZADO = 0.001  # Tamanho do "passo" na otimização (ex: 0.1, 0.01, 0.001)
EPOCAS = 100             # Quantas vezes a rede verá todo o dataset
TAMANHO_LOTE = 3     # Batch size 
tf.keras.utils.set_random_seed(42)

# %% [markdown]
# Aplicando o treinamento

# %%
#Construção da arquitetura

#Camada de Entrada
model_mlp = Sequential([Dense(12, # 64 Neurônio nesta camada (Z = W*X + b)
                                  input_shape=(2,), # Quantidade de variáveis que vão entrar ( Z = w1*x1 + w2*x2 + b)
                                  activation='relu') ]) # Especificando qual vai ser o tipo de ativação. Ex: reLu, linear, tanh, sigmoid...


#Camada Oculta 1
model_mlp.add(Dense(8, activation='relu'))

#Camada de Saída
model_mlp.add(Dense(1, activation='linear')) # 1 Neurônio nesta camada (Z = W*X + b) --- IGNORE ---, ativação linear para regressão


#Configuração
model_mlp.compile(
    optimizer=Adam(learning_rate=TAXA_APRENDIZADO), #Aplicação do modelo de Gradiente descendente, usando o leanning rate proposto
    loss='mse', # Qual a função da loss. Nesse caso o mse é (Z - F(x1,x2))²
    metrics=['mae'] # Erro Médio Absoluto para termos uma métrica mais legível
)

#Treinamento
historico = model_mlp.fit(
    X_train_scaled, y_train, #Indica quais são as bases
    epochs=EPOCAS, batch_size=TAMANHO_LOTE, #O batch_size é a batelada de cada iteração (epoch) que será calculada
    shuffle=False, # Manter a ordem temporal dos dados
    verbose=1 # Mude para 1 se quiser ver o log de cada época
)
# Out:
# Epoch 1/100
# c:\Projeto de Manutenção\Maintenance-prediction\.venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 15159.9971 - mae: 123.1252
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 15015.9365 - mae: 122.5392
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14771.1250 - mae: 121.5360
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14280.9150 - mae: 119.4981
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13446.8906 - mae: 115.9351
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11985.1289 - mae: 109.3687
# Epoch 7/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9907.0020 - mae: 99.2090
# Epoch 8/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7342.4229 - mae: 84.6988
# Epoch 9/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4334.1255 - mae: 62.9536
# Epoch 10/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2134.4722 - mae: 40.2845
# Epoch 11/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1136.6536 - mae: 29.1798
# Epoch 12/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 821.1900 - mae: 25.2397
# Epoch 13/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 721.1055 - mae: 23.8521
# Epoch 14/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 675.8973 - mae: 23.1466
# Epoch 15/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 645.4999 - mae: 22.6298
# Epoch 16/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 616.9041 - mae: 22.1213
# Epoch 17/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 593.1612 - mae: 21.6953
# Epoch 18/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 568.8274 - mae: 21.2456
# Epoch 19/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 545.1611 - mae: 20.7990
# Epoch 20/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 521.9249 - mae: 20.3510
# Epoch 21/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 499.0496 - mae: 19.9001
# Epoch 22/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 476.6370 - mae: 19.4482
# Epoch 23/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 454.5576 - mae: 18.9926
# Epoch 24/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 432.6019 - mae: 18.5292
# Epoch 25/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 412.7589 - mae: 18.0943
# Epoch 26/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 390.5691 - mae: 17.6047
# Epoch 27/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 370.1598 - mae: 17.1381
# Epoch 28/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 350.2299 - mae: 16.6702
# Epoch 29/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 330.5730 - mae: 16.1947
# Epoch 30/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 311.4469 - mae: 15.7188
# Epoch 31/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 292.7554 - mae: 15.2384
# Epoch 32/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 274.5112 - mae: 14.7544
# Epoch 33/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 256.8905 - mae: 14.2718
# Epoch 34/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 239.6686 - mae: 13.7834
# Epoch 35/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 222.9544 - mae: 13.2923
# Epoch 36/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 206.7900 - mae: 12.8000
# Epoch 37/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 191.1595 - mae: 12.3049
# Epoch 38/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 176.2335 - mae: 11.8126
# Epoch 39/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 161.6763 - mae: 11.3122
# Epoch 40/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 147.8353 - mae: 10.8146
# Epoch 41/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 134.6178 - mae: 10.3168
# Epoch 42/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 122.0305 - mae: 9.8191
# Epoch 43/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 110.1028 - mae: 9.3227
# Epoch 44/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 98.8391 - mae: 8.8280
# Epoch 45/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 88.2484 - mae: 8.3362
# Epoch 46/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 78.3379 - mae: 7.8479
# Epoch 47/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 69.0971 - mae: 7.3629
# Epoch 48/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 60.4550 - mae: 6.8791
# Epoch 49/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 51.8959 - mae: 6.3641
# Epoch 50/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 45.1297 - mae: 5.9204
# Epoch 51/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 38.3211 - mae: 5.4436
# Epoch 52/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.1408 - mae: 4.9691
# Epoch 53/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26.7525 - mae: 4.5157
# Epoch 54/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 22.0013 - mae: 4.0738
# Epoch 55/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 17.8878 - mae: 3.6485
# Epoch 56/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14.3711 - mae: 3.2417
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.4107 - mae: 2.8554
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9566 - mae: 2.4919
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9638 - mae: 2.1535
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3759 - mae: 1.8432
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1337 - mae: 1.5618
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1841 - mae: 1.3112
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4741 - mae: 1.0922
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9437 - mae: 0.8996
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5680 - mae: 0.7389
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3015 - mae: 0.6029
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1170 - mae: 0.4910
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9903 - mae: 0.4032
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9089 - mae: 0.3478
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8483 - mae: 0.3025
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8116 - mae: 0.2926
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7830 - mae: 0.2941
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7619 - mae: 0.2980
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7449 - mae: 0.3024
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7306 - mae: 0.3066
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7177 - mae: 0.3085
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7061 - mae: 0.3101
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6940 - mae: 0.3085
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6831 - mae: 0.3083
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6718 - mae: 0.3070
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6603 - mae: 0.3042
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6496 - mae: 0.3029
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6379 - mae: 0.3005
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6268 - mae: 0.2997
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6151 - mae: 0.2970
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6036 - mae: 0.2950
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5922 - mae: 0.2934
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5805 - mae: 0.2917
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5686 - mae: 0.2903
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5569 - mae: 0.2889
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5452 - mae: 0.2876
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5334 - mae: 0.2865
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5222 - mae: 0.2872
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5104 - mae: 0.2862
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4988 - mae: 0.2857
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4874 - mae: 0.2855
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4762 - mae: 0.2858
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4645 - mae: 0.2856
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4529 - mae: 0.2853
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4415 - mae: 0.2850

# %%
model_mlp.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                │ (None, 12)             │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 8)              │           104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 449 (1.76 KB)
#  Trainable params: 149 (596.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 300 (1.18 KB)

# %%
# get_weights() retorna uma lista: o primeiro item é a matriz de pesos (W), o segundo é o viés (b)
pesos, vies = model_mlp.get_layer(index=0).get_weights()

print(f"pesos: {pesos.flatten()} e o viés: {vies[0]:.4f}")
# Out:
# pesos: [ 0.9236564   0.13543083  0.3084648   1.0732564  -0.5524477   0.19555011
#   0.24199608 -0.4348051   0.0246369   1.2591434  -0.06276892 -0.07023454
#   1.0731704  -0.10792431  0.50951093  0.84136575 -0.62999946 -0.3915674
#  -0.34604567 -0.5676833  -0.6053648   1.5107703   1.025255   -0.31090704] e o viés: 1.7878

# %%
data_min = scaler.data_min_
scale = scaler.scale_

# w = pesos / scale (scale is the range: 1/(max - min))
w = pesos / scale[:, np.newaxis]
b_raw = vies - np.dot(data_min, w)

w_escalar = w[0][0]
b_raw_escalar = b_raw[0]

print(f"Pesos desnormalizados: {w.flatten()}")
print(f"Viés desnormalizado: {b_raw_escalar:.4f}")
# Out:
# Pesos desnormalizados: [ 2.5381172   0.37215063  0.847631    2.9492033  -1.518072    0.5373525
#   0.6649815  -1.1948017   0.06769979  3.4600024  -0.17248283 -0.19299762
#   2.948967   -0.2965654   1.400086    2.3119905  -1.7311767  -1.0759888
#  -0.95089954 -1.559938   -1.663483    4.1514487   2.8173     -0.85434204]
# Viés desnormalizado: -667.7812

# %%
plt.figure(figsize=(10, 5))

# Plotando a Perda (MSE)
plt.subplot(1, 2, 1)
plt.plot(historico.history['loss'], label='Erro Quadrático Médio (MSE)', color='red')
plt.title('Curva de Aprendizado - Loss')
plt.xlabel('Épocas')
plt.ylabel('MSE')
plt.legend()
plt.grid(True)

# Plotando a Métrica (MAE)
plt.subplot(1, 2, 2)
plt.plot(historico.history['mae'], label='Erro Médio Absoluto (MAE)', color='blue')
plt.title('Evolução da Métrica - MAE')
plt.xlabel('Épocas')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
erro_simples = model_mlp.evaluate(X_test_scaled, y_test, verbose=0)[1]
print(f"Erro Médio Absoluto (Simples): {erro_simples:.2f}\n")
# Out:
# Erro Médio Absoluto (Simples): 0.13

# %% [markdown]
# Valores Reais para testar previsões

# %%
plt.figure(figsize=(10, 6))
y_pred = model_mlp.predict(X_test_scaled)   
plt.plot(y_test, label='Valores Reais', marker='o')
plt.plot(y_pred, label='Previsões MLP', marker='x')
plt.title('Previsões vs Valores Reais - MLP')
plt.xlabel('Amostras de Teste')
plt.ylabel('Voltage')
plt.legend()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

current_input = X_test_scaled[0].copy().reshape(1, -1) 
recurrent_prediction = []
n_steps = 15

# Parâmetros do MinMaxScaler para a coluna 0 (shift_1)
min_voltagem = scaler.data_min_[0]
fator_escala = scaler.scale_[0]

for _ in range(n_steps):
    # Previsão da voltagem real
    next_pred = model_mlp.predict(current_input, verbose=0)[0][0]  
    recurrent_prediction.append(next_pred)  
    
    next_pred_scaled = (next_pred - min_voltagem) * fator_escala
    
    current_input = np.roll(current_input, shift=1, axis=1)  
    
    current_input[0, 0] = next_pred_scaled


y_true_50 = y_test[:n_steps].flatten()

mse = mean_squared_error(y_true_50, recurrent_prediction)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true_50, recurrent_prediction)

print(f"MSE:  {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}\n")

plt.figure(figsize=(10, 6))

plt.plot(y_true_50, label='Valores Reais', marker='o', color='dodgerblue', alpha=0.8)
plt.plot(recurrent_prediction, label='Previsões Recursivas MLP', marker='X', color='crimson', linestyle='--', alpha=0.9)

plt.title(f'Previsões Recursivas vs Valores Reais - MLP (Primeiros {n_steps} Passos)')
plt.xlabel('Passos de Tempo (Futuro)')
plt.ylabel('Voltage')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# MSE:  0.0785
# RMSE: 0.2802
# MAE:  0.2176

# %%
# SEtar todas as variáveis em um único local como dicionário
